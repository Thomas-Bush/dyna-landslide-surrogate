# %%
import sys
# append the path of the parent directory
sys.path.append("..")

# External library imports
import torch
import torch.nn as nn
import numpy as np
import random
from torch.optim import Adam
from torch.utils.data import DataLoader, Subset, random_split

# internal library imports

# internal library imports
from dataset import DebrisStateSeriesDataset
from model import ConvLSTM, ConvLSTMComplex, UNetLSTM
from train import TrainerSeries
from train import CustomDebrisLoss
from util.setting_utils import set_seed

# %%
# Set the random seed for multiple libraries to ensure repeatability

set_seed(42)

# %%
# Parameters

root_dir = r'/home/tom/repos/dyna-landslide-surrogate/data_small'
checkpoint_dir = r'/home/tom/repos/dyna-landslide-surrogate/checkpoints'
batch_size = 64
split_proportions = (0.7, 0.15, 0.15)
epochs = 50
seq_length = 5  # Specify the sequence length for the ConvLSTMUNet
array_size = 256

in_channels = 3  # Number of input channels (e.g., terrain, velocity, thickness)
out_channels = 2  # Number of output channels (e.g., next velocity, next thickness)
hidden_dim = 64  # Hidden dimension of the ConvLSTM
kernel_size = (3, 3)  # Kernel size of the ConvLSTM

# %%
# # Data set up

# # Initialize dataset with scaling
# dataset = DebrisStateSeriesDataset(root_dir=root_dir, array_size=256, apply_scaling=True, sequence_length=seq_length)

# # Split dataset into train, validation, and test sets and create dataloaders
# train_loader, val_loader, test_loader = dataset.create_dataloaders(split_proportions, batch_size, random_state=42)

# # Compute scaling factors based on the train dataset, but only if scaling is applied
# if dataset.apply_scaling:
#     train_dataset = train_loader.dataset.dataset 
#     dataset.compute_scaling_factors()

# Initialize dataset with scaling
dataset = DebrisStateSeriesDataset(root_dir=root_dir, array_size=array_size, apply_scaling=True, sequence_length=seq_length, timestep_interval=5)
# dataset = DebrisStateSeriesDataset(root_dir=root_dir, array_size=array_size, apply_scaling=True, sequence_length=seq_length)

# Split dataset into train, validation, and test sets and create dataloaders
train_loader, val_loader, test_loader = dataset.create_dataloaders(split_proportions, batch_size, random_state=42)

# Dataset stats
print(f"Total dataset size: {len(dataset)}")
print(f"Train size: {len(train_loader.dataset)}, Validation size: {len(val_loader.dataset)}, Test size: {len(test_loader.dataset)}")

print(dataset.scaling_factors)
# Out:
# Total dataset size: 2093
# Train size: 1527, Validation size: 278, Test size: 288
# (0.0, 267.08, 0.0, 30.0, 0.0, 8.0)

# %%
sequence_filenames = dataset.get_sequence_filenames()

# %%
# Print the filenames for each sequence
for i, filenames in enumerate(sequence_filenames):
    print(f"Sequence {i+1}:")
    print("Velocity sequence:", filenames['velocity_sequence'])
    print("Thickness sequence:", filenames['thickness_sequence'])
    print("Next velocity:", filenames['next_velocity'])
    print("Next thickness:", filenames['next_thickness'])
    print()
# Out:
# Sequence 1:
# Velocity sequence: ['00100_velocity_2.npy', '00100_velocity_7.npy', '00100_velocity_12.npy', '00100_velocity_17.npy', '00100_velocity_22.npy']
# Thickness sequence: ['00100_thickness_2.npy', '00100_thickness_7.npy', '00100_thickness_12.npy', '00100_thickness_17.npy', '00100_thickness_22.npy']
# Next velocity: 00100_velocity_27.npy
# Next thickness: 00100_thickness_27.npy
#
# Sequence 2:
# Velocity sequence: ['00100_velocity_3.npy', '00100_velocity_8.npy', '00100_velocity_13.npy', '00100_velocity_18.npy', '00100_velocity_23.npy']
# Thickness sequence: ['00100_thickness_3.npy', '00100_thickness_8.npy', '00100_thickness_13.npy', '00100_thickness_18.npy', '00100_thickness_23.npy']
# Next velocity: 00100_velocity_28.npy
# Next thickness: 00100_thickness_28.npy
#
# Sequence 3:
# Velocity sequence: ['00100_velocity_4.npy', '00100_velocity_9.npy', '00100_velocity_14.npy', '00100_velocity_19.npy', '00100_velocity_24.npy']
# Thickness sequence: ['00100_thickness_4.npy', '00100_thickness_9.npy', '00100_thickness_14.npy', '00100_thickness_19.npy', '00100_thickness_24.npy']
# Next velocity: 00100_velocity_29.npy
# Next thickness: 00100_thickness_29.npy
#
# Sequence 4:
# Velocity sequence: ['00100_velocity_5.npy', '00100_velocity_10.npy', '00100_velocity_15.npy', '00100_velocity_20.npy', '00100_velocity_25.npy']
# Thickness sequence: ['00100_thickness_5.npy', '00100_thickness_10.npy', '00100_thickness_15.npy', '00100_thickness_20.npy', '00100_thickness_25.npy']
# Next velocity: 00100_velocity_30.npy
# Next thickness: 00100_thickness_30.npy
#
# Sequence 5:
# Velocity sequence: ['00100_velocity_6.npy', '00100_velocity_11.npy', '00100_velocity_16.npy', '00100_velocity_21.npy', '00100_velocity_26.npy']
# Thickness sequence: ['00100_thickness_6.npy', '00100_thickness_11.npy', '00100_thickness_16.npy', '00100_thickness_21.npy', '00100_thickness_26.npy']
# Next velocity: 00100_velocity_31.npy
# Next thickness: 00100_thickness_31.npy
#
# Sequence 6:
# Velocity sequence: ['00100_velocity_7.npy', '00100_velocity_12.npy', '00100_velocity_17.npy', '00100_velocity_22.npy', '00100_velocity_27.npy']
# Thickness sequence: ['00100_thickness_7.npy', '00100_thickness_12.npy', '00100_thickness_17.npy', '00100_thickness_22.npy', '00100_thickness_27.npy']
# Next velocity: 00100_velocity_32.npy
# Next thickness: 00100_thickness_32.npy
#
# Sequence 7:
# Velocity sequence: ['00100_velocity_8.npy', '00100_velocity_13.npy', '00100_velocity_18.npy', '00100_velocity_23.npy', '00100_velocity_28.npy']
# Thickness sequence: ['00100_thickness_8.npy', '00100_thickness_13.npy', '00100_thickness_18.npy', '00100_thickness_23.npy', '00100_thickness_28.npy']
# Next velocity: 00100_velocity_33.npy
# Next thickness: 00100_thickness_33.npy
#
# Sequence 8:
# Velocity sequence: ['00100_velocity_9.npy', '00100_velocity_14.npy', '00100_velocity_19.npy', '00100_velocity_24.npy', '00100_velocity_29.npy']
# Thickness sequence: ['00100_thickness_9.npy', '00100_thickness_14.npy', '00100_thickness_19.npy', '00100_thickness_24.npy', '00100_thickness_29.npy']
# Next velocity: 00100_velocity_34.npy
# Next thickness: 00100_thickness_34.npy
#
# Sequence 9:
# Velocity sequence: ['00100_velocity_10.npy', '00100_velocity_15.npy', '00100_velocity_20.npy', '00100_velocity_25.npy', '00100_velocity_30.npy']
# Thickness sequence: ['00100_thickness_10.npy', '00100_thickness_15.npy', '00100_thickness_20.npy', '00100_thickness_25.npy', '00100_thickness_30.npy']
# Next velocity: 00100_velocity_35.npy
# Next thickness: 00100_thickness_35.npy
#
# Sequence 10:
# Velocity sequence: ['00100_velocity_11.npy', '00100_velocity_16.npy', '00100_velocity_21.npy', '00100_velocity_26.npy', '00100_velocity_31.npy']
# Thickness sequence: ['00100_thickness_11.npy', '00100_thickness_16.npy', '00100_thickness_21.npy', '00100_thickness_26.npy', '00100_thickness_31.npy']
# Next velocity: 00100_velocity_36.npy
# Next thickness: 00100_thickness_36.npy
#
# Sequence 11:
# Velocity sequence: ['00100_velocity_12.npy', '00100_velocity_17.npy', '00100_velocity_22.npy', '00100_velocity_27.npy', '00100_velocity_32.npy']
# Thickness sequence: ['00100_thickness_12.npy', '00100_thickness_17.npy', '00100_thickness_22.npy', '00100_thickness_27.npy', '00100_thickness_32.npy']
# Next velocity: 00100_velocity_37.npy
# Next thickness: 00100_thickness_37.npy
#
# Sequence 12:
# Velocity sequence: ['00100_velocity_13.npy', '00100_velocity_18.npy', '00100_velocity_23.npy', '00100_velocity_28.npy', '00100_velocity_33.npy']
# Thickness sequence: ['00100_thickness_13.npy', '00100_thickness_18.npy', '00100_thickness_23.npy', '00100_thickness_28.npy', '00100_thickness_33.npy']
# Next velocity: 00100_velocity_38.npy
# Next thickness: 00100_thickness_38.npy
#
# Sequence 13:
# Velocity sequence: ['00100_velocity_14.npy', '00100_velocity_19.npy', '00100_velocity_24.npy', '00100_velocity_29.npy', '00100_velocity_34.npy']
# Thickness sequence: ['00100_thickness_14.npy', '00100_thickness_19.npy', '00100_thickness_24.npy', '00100_thickness_29.npy', '00100_thickness_34.npy']
# Next velocity: 00100_velocity_39.npy
# Next thickness: 00100_thickness_39.npy
#
# Sequence 14:
# Velocity sequence: ['00100_velocity_15.npy', '00100_velocity_20.npy', '00100_velocity_25.npy', '00100_velocity_30.npy', '00100_velocity_35.npy']
# Thickness sequence: ['00100_thickness_15.npy', '00100_thickness_20.npy', '00100_thickness_25.npy', '00100_thickness_30.npy', '00100_thickness_35.npy']
# Next velocity: 00100_velocity_40.npy
# Next thickness: 00100_thickness_40.npy
#
# Sequence 15:
# Velocity sequence: ['00100_velocity_16.npy', '00100_velocity_21.npy', '00100_velocity_26.npy', '00100_velocity_31.npy', '00100_velocity_36.npy']
# Thickness sequence: ['00100_thickness_16.npy', '00100_thickness_21.npy', '00100_thickness_26.npy', '00100_thickness_31.npy', '00100_thickness_36.npy']
# Next velocity: 00100_velocity_41.npy
# Next thickness: 00100_thickness_41.npy
#
# Sequence 16:
# Velocity sequence: ['00100_velocity_17.npy', '00100_velocity_22.npy', '00100_velocity_27.npy', '00100_velocity_32.npy', '00100_velocity_37.npy']
# Thickness sequence: ['00100_thickness_17.npy', '00100_thickness_22.npy', '00100_thickness_27.npy', '00100_thickness_32.npy', '00100_thickness_37.npy']
# Next velocity: 00100_velocity_42.npy
# Next thickness: 00100_thickness_42.npy
#
# Sequence 17:
# Velocity sequence: ['00100_velocity_18.npy', '00100_velocity_23.npy', '00100_velocity_28.npy', '00100_velocity_33.npy', '00100_velocity_38.npy']
# Thickness sequence: ['00100_thickness_18.npy', '00100_thickness_23.npy', '00100_thickness_28.npy', '00100_thickness_33.npy', '00100_thickness_38.npy']
# Next velocity: 00100_velocity_43.npy
# Next thickness: 00100_thickness_43.npy
#
# Sequence 18:
# Velocity sequence: ['00100_velocity_19.npy', '00100_velocity_24.npy', '00100_velocity_29.npy', '00100_velocity_34.npy', '00100_velocity_39.npy']
# Thickness sequence: ['00100_thickness_19.npy', '00100_thickness_24.npy', '00100_thickness_29.npy', '00100_thickness_34.npy', '00100_thickness_39.npy']
# Next velocity: 00100_velocity_44.npy
# Next thickness: 00100_thickness_44.npy
#
# Sequence 19:
# Velocity sequence: ['00100_velocity_20.npy', '00100_velocity_25.npy', '00100_velocity_30.npy', '00100_velocity_35.npy', '00100_velocity_40.npy']
# Thickness sequence: ['00100_thickness_20.npy', '00100_thickness_25.npy', '00100_thickness_30.npy', '00100_thickness_35.npy', '00100_thickness_40.npy']
# Next velocity: 00100_velocity_45.npy
# Next thickness: 00100_thickness_45.npy
#
# Sequence 20:
# Velocity sequence: ['00100_velocity_21.npy', '00100_velocity_26.npy', '00100_velocity_31.npy', '00100_velocity_36.npy', '00100_velocity_41.npy']
# Thickness sequence: ['00100_thickness_21.npy', '00100_thickness_26.npy', '00100_thickness_31.npy', '00100_thickness_36.npy', '00100_thickness_41.npy']
# Next velocity: 00100_velocity_46.npy
# Next thickness: 00100_thickness_46.npy
#
# Sequence 21:
# Velocity sequence: ['00100_velocity_22.npy', '00100_velocity_27.npy', '00100_velocity_32.npy', '00100_velocity_37.npy', '00100_velocity_42.npy']
# Thickness sequence: ['00100_thickness_22.npy', '00100_thickness_27.npy', '00100_thickness_32.npy', '00100_thickness_37.npy', '00100_thickness_42.npy']
# Next velocity: 00100_velocity_47.npy
# Next thickness: 00100_thickness_47.npy
#
# Sequence 22:
# Velocity sequence: ['00100_velocity_23.npy', '00100_velocity_28.npy', '00100_velocity_33.npy', '00100_velocity_38.npy', '00100_velocity_43.npy']
# Thickness sequence: ['00100_thickness_23.npy', '00100_thickness_28.npy', '00100_thickness_33.npy', '00100_thickness_38.npy', '00100_thickness_43.npy']
# Next velocity: 00100_velocity_48.npy
# Next thickness: 00100_thickness_48.npy
#
# Sequence 23:
# Velocity sequence: ['00100_velocity_24.npy', '00100_velocity_29.npy', '00100_velocity_34.npy', '00100_velocity_39.npy', '00100_velocity_44.npy']
# Thickness sequence: ['00100_thickness_24.npy', '00100_thickness_29.npy', '00100_thickness_34.npy', '00100_thickness_39.npy', '00100_thickness_44.npy']
# Next velocity: 00100_velocity_49.npy
# Next thickness: 00100_thickness_49.npy
#
# Sequence 24:
# Velocity sequence: ['00100_velocity_25.npy', '00100_velocity_30.npy', '00100_velocity_35.npy', '00100_velocity_40.npy', '00100_velocity_45.npy']
# Thickness sequence: ['00100_thickness_25.npy', '00100_thickness_30.npy', '00100_thickness_35.npy', '00100_thickness_40.npy', '00100_thickness_45.npy']
# Next velocity: 00100_velocity_50.npy
# Next thickness: 00100_thickness_50.npy
#
# Sequence 25:
# Velocity sequence: ['00100_velocity_26.npy', '00100_velocity_31.npy', '00100_velocity_36.npy', '00100_velocity_41.npy', '00100_velocity_46.npy']
# Thickness sequence: ['00100_thickness_26.npy', '00100_thickness_31.npy', '00100_thickness_36.npy', '00100_thickness_41.npy', '00100_thickness_46.npy']
# Next velocity: 00100_velocity_51.npy
# Next thickness: 00100_thickness_51.npy
#
# Sequence 26:
# Velocity sequence: ['00100_velocity_27.npy', '00100_velocity_32.npy', '00100_velocity_37.npy', '00100_velocity_42.npy', '00100_velocity_47.npy']
# Thickness sequence: ['00100_thickness_27.npy', '00100_thickness_32.npy', '00100_thickness_37.npy', '00100_thickness_42.npy', '00100_thickness_47.npy']
# Next velocity: 00100_velocity_52.npy
# Next thickness: 00100_thickness_52.npy
#
# Sequence 27:
# Velocity sequence: ['00100_velocity_28.npy', '00100_velocity_33.npy', '00100_velocity_38.npy', '00100_velocity_43.npy', '00100_velocity_48.npy']
# Thickness sequence: ['00100_thickness_28.npy', '00100_thickness_33.npy', '00100_thickness_38.npy', '00100_thickness_43.npy', '00100_thickness_48.npy']
# Next velocity: 00100_velocity_53.npy
# Next thickness: 00100_thickness_53.npy
#
# Sequence 28:
# Velocity sequence: ['00100_velocity_29.npy', '00100_velocity_34.npy', '00100_velocity_39.npy', '00100_velocity_44.npy', '00100_velocity_49.npy']
# Thickness sequence: ['00100_thickness_29.npy', '00100_thickness_34.npy', '00100_thickness_39.npy', '00100_thickness_44.npy', '00100_thickness_49.npy']
# Next velocity: 00100_velocity_54.npy
# Next thickness: 00100_thickness_54.npy
#
# Sequence 29:
# Velocity sequence: ['00100_velocity_30.npy', '00100_velocity_35.npy', '00100_velocity_40.npy', '00100_velocity_45.npy', '00100_velocity_50.npy']
# Thickness sequence: ['00100_thickness_30.npy', '00100_thickness_35.npy', '00100_thickness_40.npy', '00100_thickness_45.npy', '00100_thickness_50.npy']
# Next velocity: 00100_velocity_55.npy
# Next thickness: 00100_thickness_55.npy
#
# Sequence 30:
# Velocity sequence: ['00100_velocity_31.npy', '00100_velocity_36.npy', '00100_velocity_41.npy', '00100_velocity_46.npy', '00100_velocity_51.npy']
# Thickness sequence: ['00100_thickness_31.npy', '00100_thickness_36.npy', '00100_thickness_41.npy', '00100_thickness_46.npy', '00100_thickness_51.npy']
# Next velocity: 00100_velocity_56.npy
# Next thickness: 00100_thickness_56.npy
#
# Sequence 31:
# Velocity sequence: ['00100_velocity_32.npy', '00100_velocity_37.npy', '00100_velocity_42.npy', '00100_velocity_47.npy', '00100_velocity_52.npy']
# Thickness sequence: ['00100_thickness_32.npy', '00100_thickness_37.npy', '00100_thickness_42.npy', '00100_thickness_47.npy', '00100_thickness_52.npy']
# Next velocity: 00100_velocity_57.npy
# Next thickness: 00100_thickness_57.npy
#
# Sequence 32:
# Velocity sequence: ['00100_velocity_33.npy', '00100_velocity_38.npy', '00100_velocity_43.npy', '00100_velocity_48.npy', '00100_velocity_53.npy']
# Thickness sequence: ['00100_thickness_33.npy', '00100_thickness_38.npy', '00100_thickness_43.npy', '00100_thickness_48.npy', '00100_thickness_53.npy']
# Next velocity: 00100_velocity_58.npy
# Next thickness: 00100_thickness_58.npy
#
# Sequence 33:
# Velocity sequence: ['00100_velocity_34.npy', '00100_velocity_39.npy', '00100_velocity_44.npy', '00100_velocity_49.npy', '00100_velocity_54.npy']
# Thickness sequence: ['00100_thickness_34.npy', '00100_thickness_39.npy', '00100_thickness_44.npy', '00100_thickness_49.npy', '00100_thickness_54.npy']
# Next velocity: 00100_velocity_59.npy
# Next thickness: 00100_thickness_59.npy
#
# Sequence 34:
# Velocity sequence: ['00100_velocity_35.npy', '00100_velocity_40.npy', '00100_velocity_45.npy', '00100_velocity_50.npy', '00100_velocity_55.npy']
# Thickness sequence: ['00100_thickness_35.npy', '00100_thickness_40.npy', '00100_thickness_45.npy', '00100_thickness_50.npy', '00100_thickness_55.npy']
# Next velocity: 00100_velocity_60.npy
# Next thickness: 00100_thickness_60.npy
#
# Sequence 35:
# Velocity sequence: ['00100_velocity_36.npy', '00100_velocity_41.npy', '00100_velocity_46.npy', '00100_velocity_51.npy', '00100_velocity_56.npy']
# Thickness sequence: ['00100_thickness_36.npy', '00100_thickness_41.npy', '00100_thickness_46.npy', '00100_thickness_51.npy', '00100_thickness_56.npy']
# Next velocity: 00100_velocity_61.npy
# Next thickness: 00100_thickness_61.npy
#
# Sequence 36:
# Velocity sequence: ['00100_velocity_37.npy', '00100_velocity_42.npy', '00100_velocity_47.npy', '00100_velocity_52.npy', '00100_velocity_57.npy']
# Thickness sequence: ['00100_thickness_37.npy', '00100_thickness_42.npy', '00100_thickness_47.npy', '00100_thickness_52.npy', '00100_thickness_57.npy']
# Next velocity: 00100_velocity_62.npy
# Next thickness: 00100_thickness_62.npy
#
# Sequence 37:
# Velocity sequence: ['00289_velocity_2.npy', '00289_velocity_7.npy', '00289_velocity_12.npy', '00289_velocity_17.npy', '00289_velocity_22.npy']
# Thickness sequence: ['00289_thickness_2.npy', '00289_thickness_7.npy', '00289_thickness_12.npy', '00289_thickness_17.npy', '00289_thickness_22.npy']
# Next velocity: 00289_velocity_27.npy
# Next thickness: 00289_thickness_27.npy
#
# Sequence 38:
# Velocity sequence: ['00289_velocity_3.npy', '00289_velocity_8.npy', '00289_velocity_13.npy', '00289_velocity_18.npy', '00289_velocity_23.npy']
# Thickness sequence: ['00289_thickness_3.npy', '00289_thickness_8.npy', '00289_thickness_13.npy', '00289_thickness_18.npy', '00289_thickness_23.npy']
# Next velocity: 00289_velocity_28.npy
# Next thickness: 00289_thickness_28.npy
#
# Sequence 39:
# Velocity sequence: ['00289_velocity_4.npy', '00289_velocity_9.npy', '00289_velocity_14.npy', '00289_velocity_19.npy', '00289_velocity_24.npy']
# Thickness sequence: ['00289_thickness_4.npy', '00289_thickness_9.npy', '00289_thickness_14.npy', '00289_thickness_19.npy', '00289_thickness_24.npy']
# Next velocity: 00289_velocity_29.npy
# Next thickness: 00289_thickness_29.npy
#
# Sequence 40:
# Velocity sequence: ['00289_velocity_5.npy', '00289_velocity_10.npy', '00289_velocity_15.npy', '00289_velocity_20.npy', '00289_velocity_25.npy']
# Thickness sequence: ['00289_thickness_5.npy', '00289_thickness_10.npy', '00289_thickness_15.npy', '00289_thickness_20.npy', '00289_thickness_25.npy']
# Next velocity: 00289_velocity_30.npy
# Next thickness: 00289_thickness_30.npy
#
# Sequence 41:
# Velocity sequence: ['00289_velocity_6.npy', '00289_velocity_11.npy', '00289_velocity_16.npy', '00289_velocity_21.npy', '00289_velocity_26.npy']
# Thickness sequence: ['00289_thickness_6.npy', '00289_thickness_11.npy', '00289_thickness_16.npy', '00289_thickness_21.npy', '00289_thickness_26.npy']
# Next velocity: 00289_velocity_31.npy
# Next thickness: 00289_thickness_31.npy
#
# Sequence 42:
# Velocity sequence: ['00289_velocity_7.npy', '00289_velocity_12.npy', '00289_velocity_17.npy', '00289_velocity_22.npy', '00289_velocity_27.npy']
# Thickness sequence: ['00289_thickness_7.npy', '00289_thickness_12.npy', '00289_thickness_17.npy', '00289_thickness_22.npy', '00289_thickness_27.npy']
# Next velocity: 00289_velocity_32.npy
# Next thickness: 00289_thickness_32.npy
#
# Sequence 43:
# Velocity sequence: ['00289_velocity_8.npy', '00289_velocity_13.npy', '00289_velocity_18.npy', '00289_velocity_23.npy', '00289_velocity_28.npy']
# Thickness sequence: ['00289_thickness_8.npy', '00289_thickness_13.npy', '00289_thickness_18.npy', '00289_thickness_23.npy', '00289_thickness_28.npy']
# Next velocity: 00289_velocity_33.npy
# Next thickness: 00289_thickness_33.npy
#
# Sequence 44:
# Velocity sequence: ['00289_velocity_9.npy', '00289_velocity_14.npy', '00289_velocity_19.npy', '00289_velocity_24.npy', '00289_velocity_29.npy']
# Thickness sequence: ['00289_thickness_9.npy', '00289_thickness_14.npy', '00289_thickness_19.npy', '00289_thickness_24.npy', '00289_thickness_29.npy']
# Next velocity: 00289_velocity_34.npy
# Next thickness: 00289_thickness_34.npy
#
# Sequence 45:
# Velocity sequence: ['00289_velocity_10.npy', '00289_velocity_15.npy', '00289_velocity_20.npy', '00289_velocity_25.npy', '00289_velocity_30.npy']
# Thickness sequence: ['00289_thickness_10.npy', '00289_thickness_15.npy', '00289_thickness_20.npy', '00289_thickness_25.npy', '00289_thickness_30.npy']
# Next velocity: 00289_velocity_35.npy
# Next thickness: 00289_thickness_35.npy
#
# Sequence 46:
# Velocity sequence: ['00289_velocity_11.npy', '00289_velocity_16.npy', '00289_velocity_21.npy', '00289_velocity_26.npy', '00289_velocity_31.npy']
# Thickness sequence: ['00289_thickness_11.npy', '00289_thickness_16.npy', '00289_thickness_21.npy', '00289_thickness_26.npy', '00289_thickness_31.npy']
# Next velocity: 00289_velocity_36.npy
# Next thickness: 00289_thickness_36.npy
#
# Sequence 47:
# Velocity sequence: ['00289_velocity_12.npy', '00289_velocity_17.npy', '00289_velocity_22.npy', '00289_velocity_27.npy', '00289_velocity_32.npy']
# Thickness sequence: ['00289_thickness_12.npy', '00289_thickness_17.npy', '00289_thickness_22.npy', '00289_thickness_27.npy', '00289_thickness_32.npy']
# Next velocity: 00289_velocity_37.npy
# Next thickness: 00289_thickness_37.npy
#
# Sequence 48:
# Velocity sequence: ['00289_velocity_13.npy', '00289_velocity_18.npy', '00289_velocity_23.npy', '00289_velocity_28.npy', '00289_velocity_33.npy']
# Thickness sequence: ['00289_thickness_13.npy', '00289_thickness_18.npy', '00289_thickness_23.npy', '00289_thickness_28.npy', '00289_thickness_33.npy']
# Next velocity: 00289_velocity_38.npy
# Next thickness: 00289_thickness_38.npy
#
# Sequence 49:
# Velocity sequence: ['00289_velocity_14.npy', '00289_velocity_19.npy', '00289_velocity_24.npy', '00289_velocity_29.npy', '00289_velocity_34.npy']
# Thickness sequence: ['00289_thickness_14.npy', '00289_thickness_19.npy', '00289_thickness_24.npy', '00289_thickness_29.npy', '00289_thickness_34.npy']
# Next velocity: 00289_velocity_39.npy
# Next thickness: 00289_thickness_39.npy
#
# Sequence 50:
# Velocity sequence: ['00289_velocity_15.npy', '00289_velocity_20.npy', '00289_velocity_25.npy', '00289_velocity_30.npy', '00289_velocity_35.npy']
# Thickness sequence: ['00289_thickness_15.npy', '00289_thickness_20.npy', '00289_thickness_25.npy', '00289_thickness_30.npy', '00289_thickness_35.npy']
# Next velocity: 00289_velocity_40.npy
# Next thickness: 00289_thickness_40.npy
#
# Sequence 51:
# Velocity sequence: ['00289_velocity_16.npy', '00289_velocity_21.npy', '00289_velocity_26.npy', '00289_velocity_31.npy', '00289_velocity_36.npy']
# Thickness sequence: ['00289_thickness_16.npy', '00289_thickness_21.npy', '00289_thickness_26.npy', '00289_thickness_31.npy', '00289_thickness_36.npy']
# Next velocity: 00289_velocity_41.npy
# Next thickness: 00289_thickness_41.npy
#
# Sequence 52:
# Velocity sequence: ['00289_velocity_17.npy', '00289_velocity_22.npy', '00289_velocity_27.npy', '00289_velocity_32.npy', '00289_velocity_37.npy']
# Thickness sequence: ['00289_thickness_17.npy', '00289_thickness_22.npy', '00289_thickness_27.npy', '00289_thickness_32.npy', '00289_thickness_37.npy']
# Next velocity: 00289_velocity_42.npy
# Next thickness: 00289_thickness_42.npy
#
# Sequence 53:
# Velocity sequence: ['00289_velocity_18.npy', '00289_velocity_23.npy', '00289_velocity_28.npy', '00289_velocity_33.npy', '00289_velocity_38.npy']
# Thickness sequence: ['00289_thickness_18.npy', '00289_thickness_23.npy', '00289_thickness_28.npy', '00289_thickness_33.npy', '00289_thickness_38.npy']
# Next velocity: 00289_velocity_43.npy
# Next thickness: 00289_thickness_43.npy
#
# Sequence 54:
# Velocity sequence: ['00289_velocity_19.npy', '00289_velocity_24.npy', '00289_velocity_29.npy', '00289_velocity_34.npy', '00289_velocity_39.npy']
# Thickness sequence: ['00289_thickness_19.npy', '00289_thickness_24.npy', '00289_thickness_29.npy', '00289_thickness_34.npy', '00289_thickness_39.npy']
# Next velocity: 00289_velocity_44.npy
# Next thickness: 00289_thickness_44.npy
#
# Sequence 55:
# Velocity sequence: ['00289_velocity_20.npy', '00289_velocity_25.npy', '00289_velocity_30.npy', '00289_velocity_35.npy', '00289_velocity_40.npy']
# Thickness sequence: ['00289_thickness_20.npy', '00289_thickness_25.npy', '00289_thickness_30.npy', '00289_thickness_35.npy', '00289_thickness_40.npy']
# Next velocity: 00289_velocity_45.npy
# Next thickness: 00289_thickness_45.npy
#
# Sequence 56:
# Velocity sequence: ['00289_velocity_21.npy', '00289_velocity_26.npy', '00289_velocity_31.npy', '00289_velocity_36.npy', '00289_velocity_41.npy']
# Thickness sequence: ['00289_thickness_21.npy', '00289_thickness_26.npy', '00289_thickness_31.npy', '00289_thickness_36.npy', '00289_thickness_41.npy']
# Next velocity: 00289_velocity_46.npy
# Next thickness: 00289_thickness_46.npy
#
# Sequence 57:
# Velocity sequence: ['00289_velocity_22.npy', '00289_velocity_27.npy', '00289_velocity_32.npy', '00289_velocity_37.npy', '00289_velocity_42.npy']
# Thickness sequence: ['00289_thickness_22.npy', '00289_thickness_27.npy', '00289_thickness_32.npy', '00289_thickness_37.npy', '00289_thickness_42.npy']
# Next velocity: 00289_velocity_47.npy
# Next thickness: 00289_thickness_47.npy
#
# Sequence 58:
# Velocity sequence: ['00289_velocity_23.npy', '00289_velocity_28.npy', '00289_velocity_33.npy', '00289_velocity_38.npy', '00289_velocity_43.npy']
# Thickness sequence: ['00289_thickness_23.npy', '00289_thickness_28.npy', '00289_thickness_33.npy', '00289_thickness_38.npy', '00289_thickness_43.npy']
# Next velocity: 00289_velocity_48.npy
# Next thickness: 00289_thickness_48.npy
#
# Sequence 59:
# Velocity sequence: ['00289_velocity_24.npy', '00289_velocity_29.npy', '00289_velocity_34.npy', '00289_velocity_39.npy', '00289_velocity_44.npy']
# Thickness sequence: ['00289_thickness_24.npy', '00289_thickness_29.npy', '00289_thickness_34.npy', '00289_thickness_39.npy', '00289_thickness_44.npy']
# Next velocity: 00289_velocity_49.npy
# Next thickness: 00289_thickness_49.npy
#
# Sequence 60:
# Velocity sequence: ['00289_velocity_25.npy', '00289_velocity_30.npy', '00289_velocity_35.npy', '00289_velocity_40.npy', '00289_velocity_45.npy']
# Thickness sequence: ['00289_thickness_25.npy', '00289_thickness_30.npy', '00289_thickness_35.npy', '00289_thickness_40.npy', '00289_thickness_45.npy']
# Next velocity: 00289_velocity_50.npy
# Next thickness: 00289_thickness_50.npy
#
# Sequence 61:
# Velocity sequence: ['00289_velocity_26.npy', '00289_velocity_31.npy', '00289_velocity_36.npy', '00289_velocity_41.npy', '00289_velocity_46.npy']
# Thickness sequence: ['00289_thickness_26.npy', '00289_thickness_31.npy', '00289_thickness_36.npy', '00289_thickness_41.npy', '00289_thickness_46.npy']
# Next velocity: 00289_velocity_51.npy
# Next thickness: 00289_thickness_51.npy
#
# Sequence 62:
# Velocity sequence: ['00289_velocity_27.npy', '00289_velocity_32.npy', '00289_velocity_37.npy', '00289_velocity_42.npy', '00289_velocity_47.npy']
# Thickness sequence: ['00289_thickness_27.npy', '00289_thickness_32.npy', '00289_thickness_37.npy', '00289_thickness_42.npy', '00289_thickness_47.npy']
# Next velocity: 00289_velocity_52.npy
# Next thickness: 00289_thickness_52.npy
#
# Sequence 63:
# Velocity sequence: ['00289_velocity_28.npy', '00289_velocity_33.npy', '00289_velocity_38.npy', '00289_velocity_43.npy', '00289_velocity_48.npy']
# Thickness sequence: ['00289_thickness_28.npy', '00289_thickness_33.npy', '00289_thickness_38.npy', '00289_thickness_43.npy', '00289_thickness_48.npy']
# Next velocity: 00289_velocity_53.npy
# Next thickness: 00289_thickness_53.npy
#
# Sequence 64:
# Velocity sequence: ['00289_velocity_29.npy', '00289_velocity_34.npy', '00289_velocity_39.npy', '00289_velocity_44.npy', '00289_velocity_49.npy']
# Thickness sequence: ['00289_thickness_29.npy', '00289_thickness_34.npy', '00289_thickness_39.npy', '00289_thickness_44.npy', '00289_thickness_49.npy']
# Next velocity: 00289_velocity_54.npy
# Next thickness: 00289_thickness_54.npy
#
# Sequence 65:
# Velocity sequence: ['00289_velocity_30.npy', '00289_velocity_35.npy', '00289_velocity_40.npy', '00289_velocity_45.npy', '00289_velocity_50.npy']
# Thickness sequence: ['00289_thickness_30.npy', '00289_thickness_35.npy', '00289_thickness_40.npy', '00289_thickness_45.npy', '00289_thickness_50.npy']
# Next velocity: 00289_velocity_55.npy
# Next thickness: 00289_thickness_55.npy
#
# Sequence 66:
# Velocity sequence: ['00289_velocity_31.npy', '00289_velocity_36.npy', '00289_velocity_41.npy', '00289_velocity_46.npy', '00289_velocity_51.npy']
# Thickness sequence: ['00289_thickness_31.npy', '00289_thickness_36.npy', '00289_thickness_41.npy', '00289_thickness_46.npy', '00289_thickness_51.npy']
# Next velocity: 00289_velocity_56.npy
# Next thickness: 00289_thickness_56.npy
#
# Sequence 67:
# Velocity sequence: ['00289_velocity_32.npy', '00289_velocity_37.npy', '00289_velocity_42.npy', '00289_velocity_47.npy', '00289_velocity_52.npy']
# Thickness sequence: ['00289_thickness_32.npy', '00289_thickness_37.npy', '00289_thickness_42.npy', '00289_thickness_47.npy', '00289_thickness_52.npy']
# Next velocity: 00289_velocity_57.npy
# Next thickness: 00289_thickness_57.npy
#
# Sequence 68:
# Velocity sequence: ['00289_velocity_33.npy', '00289_velocity_38.npy', '00289_velocity_43.npy', '00289_velocity_48.npy', '00289_velocity_53.npy']
# Thickness sequence: ['00289_thickness_33.npy', '00289_thickness_38.npy', '00289_thickness_43.npy', '00289_thickness_48.npy', '00289_thickness_53.npy']
# Next velocity: 00289_velocity_58.npy
# Next thickness: 00289_thickness_58.npy
#
# Sequence 69:
# Velocity sequence: ['00289_velocity_34.npy', '00289_velocity_39.npy', '00289_velocity_44.npy', '00289_velocity_49.npy', '00289_velocity_54.npy']
# Thickness sequence: ['00289_thickness_34.npy', '00289_thickness_39.npy', '00289_thickness_44.npy', '00289_thickness_49.npy', '00289_thickness_54.npy']
# Next velocity: 00289_velocity_59.npy
# Next thickness: 00289_thickness_59.npy
#
# Sequence 70:
# Velocity sequence: ['00289_velocity_35.npy', '00289_velocity_40.npy', '00289_velocity_45.npy', '00289_velocity_50.npy', '00289_velocity_55.npy']
# Thickness sequence: ['00289_thickness_35.npy', '00289_thickness_40.npy', '00289_thickness_45.npy', '00289_thickness_50.npy', '00289_thickness_55.npy']
# Next velocity: 00289_velocity_60.npy
# Next thickness: 00289_thickness_60.npy
#
# Sequence 71:
# Velocity sequence: ['00289_velocity_36.npy', '00289_velocity_41.npy', '00289_velocity_46.npy', '00289_velocity_51.npy', '00289_velocity_56.npy']
# Thickness sequence: ['00289_thickness_36.npy', '00289_thickness_41.npy', '00289_thickness_46.npy', '00289_thickness_51.npy', '00289_thickness_56.npy']
# Next velocity: 00289_velocity_61.npy
# Next thickness: 00289_thickness_61.npy
#
# Sequence 72:
# Velocity sequence: ['00289_velocity_37.npy', '00289_velocity_42.npy', '00289_velocity_47.npy', '00289_velocity_52.npy', '00289_velocity_57.npy']
# Thickness sequence: ['00289_thickness_37.npy', '00289_thickness_42.npy', '00289_thickness_47.npy', '00289_thickness_52.npy', '00289_thickness_57.npy']
# Next velocity: 00289_velocity_62.npy
# Next thickness: 00289_thickness_62.npy
#
# Sequence 73:
# Velocity sequence: ['00289_velocity_38.npy', '00289_velocity_43.npy', '00289_velocity_48.npy', '00289_velocity_53.npy', '00289_velocity_58.npy']
# Thickness sequence: ['00289_thickness_38.npy', '00289_thickness_43.npy', '00289_thickness_48.npy', '00289_thickness_53.npy', '00289_thickness_58.npy']
# Next velocity: 00289_velocity_63.npy
# Next thickness: 00289_thickness_63.npy
#
# Sequence 74:
# Velocity sequence: ['00289_velocity_39.npy', '00289_velocity_44.npy', '00289_velocity_49.npy', '00289_velocity_54.npy', '00289_velocity_59.npy']
# Thickness sequence: ['00289_thickness_39.npy', '00289_thickness_44.npy', '00289_thickness_49.npy', '00289_thickness_54.npy', '00289_thickness_59.npy']
# Next velocity: 00289_velocity_64.npy
# Next thickness: 00289_thickness_64.npy
#
# Sequence 75:
# Velocity sequence: ['00289_velocity_40.npy', '00289_velocity_45.npy', '00289_velocity_50.npy', '00289_velocity_55.npy', '00289_velocity_60.npy']
# Thickness sequence: ['00289_thickness_40.npy', '00289_thickness_45.npy', '00289_thickness_50.npy', '00289_thickness_55.npy', '00289_thickness_60.npy']
# Next velocity: 00289_velocity_65.npy
# Next thickness: 00289_thickness_65.npy
#
# Sequence 76:
# Velocity sequence: ['00289_velocity_41.npy', '00289_velocity_46.npy', '00289_velocity_51.npy', '00289_velocity_56.npy', '00289_velocity_61.npy']
# Thickness sequence: ['00289_thickness_41.npy', '00289_thickness_46.npy', '00289_thickness_51.npy', '00289_thickness_56.npy', '00289_thickness_61.npy']
# Next velocity: 00289_velocity_66.npy
# Next thickness: 00289_thickness_66.npy
#
# Sequence 77:
# Velocity sequence: ['00289_velocity_42.npy', '00289_velocity_47.npy', '00289_velocity_52.npy', '00289_velocity_57.npy', '00289_velocity_62.npy']
# Thickness sequence: ['00289_thickness_42.npy', '00289_thickness_47.npy', '00289_thickness_52.npy', '00289_thickness_57.npy', '00289_thickness_62.npy']
# Next velocity: 00289_velocity_67.npy
# Next thickness: 00289_thickness_67.npy
#
# Sequence 78:
# Velocity sequence: ['00289_velocity_43.npy', '00289_velocity_48.npy', '00289_velocity_53.npy', '00289_velocity_58.npy', '00289_velocity_63.npy']
# Thickness sequence: ['00289_thickness_43.npy', '00289_thickness_48.npy', '00289_thickness_53.npy', '00289_thickness_58.npy', '00289_thickness_63.npy']
# Next velocity: 00289_velocity_68.npy
# Next thickness: 00289_thickness_68.npy
#
# Sequence 79:
# Velocity sequence: ['00289_velocity_44.npy', '00289_velocity_49.npy', '00289_velocity_54.npy', '00289_velocity_59.npy', '00289_velocity_64.npy']
# Thickness sequence: ['00289_thickness_44.npy', '00289_thickness_49.npy', '00289_thickness_54.npy', '00289_thickness_59.npy', '00289_thickness_64.npy']
# Next velocity: 00289_velocity_69.npy
# Next thickness: 00289_thickness_69.npy
#
# Sequence 80:
# Velocity sequence: ['00289_velocity_45.npy', '00289_velocity_50.npy', '00289_velocity_55.npy', '00289_velocity_60.npy', '00289_velocity_65.npy']
# Thickness sequence: ['00289_thickness_45.npy', '00289_thickness_50.npy', '00289_thickness_55.npy', '00289_thickness_60.npy', '00289_thickness_65.npy']
# Next velocity: 00289_velocity_70.npy
# Next thickness: 00289_thickness_70.npy
#
# Sequence 81:
# Velocity sequence: ['00289_velocity_46.npy', '00289_velocity_51.npy', '00289_velocity_56.npy', '00289_velocity_61.npy', '00289_velocity_66.npy']
# Thickness sequence: ['00289_thickness_46.npy', '00289_thickness_51.npy', '00289_thickness_56.npy', '00289_thickness_61.npy', '00289_thickness_66.npy']
# Next velocity: 00289_velocity_71.npy
# Next thickness: 00289_thickness_71.npy
#
# Sequence 82:
# Velocity sequence: ['00289_velocity_47.npy', '00289_velocity_52.npy', '00289_velocity_57.npy', '00289_velocity_62.npy', '00289_velocity_67.npy']
# Thickness sequence: ['00289_thickness_47.npy', '00289_thickness_52.npy', '00289_thickness_57.npy', '00289_thickness_62.npy', '00289_thickness_67.npy']
# Next velocity: 00289_velocity_72.npy
# Next thickness: 00289_thickness_72.npy
#
# Sequence 83:
# Velocity sequence: ['00289_velocity_48.npy', '00289_velocity_53.npy', '00289_velocity_58.npy', '00289_velocity_63.npy', '00289_velocity_68.npy']
# Thickness sequence: ['00289_thickness_48.npy', '00289_thickness_53.npy', '00289_thickness_58.npy', '00289_thickness_63.npy', '00289_thickness_68.npy']
# Next velocity: 00289_velocity_73.npy
# Next thickness: 00289_thickness_73.npy
#
# Sequence 84:
# Velocity sequence: ['00289_velocity_49.npy', '00289_velocity_54.npy', '00289_velocity_59.npy', '00289_velocity_64.npy', '00289_velocity_69.npy']
# Thickness sequence: ['00289_thickness_49.npy', '00289_thickness_54.npy', '00289_thickness_59.npy', '00289_thickness_64.npy', '00289_thickness_69.npy']
# Next velocity: 00289_velocity_74.npy
# Next thickness: 00289_thickness_74.npy
#
# Sequence 85:
# Velocity sequence: ['00289_velocity_50.npy', '00289_velocity_55.npy', '00289_velocity_60.npy', '00289_velocity_65.npy', '00289_velocity_70.npy']
# Thickness sequence: ['00289_thickness_50.npy', '00289_thickness_55.npy', '00289_thickness_60.npy', '00289_thickness_65.npy', '00289_thickness_70.npy']
# Next velocity: 00289_velocity_75.npy
# Next thickness: 00289_thickness_75.npy
#
# Sequence 86:
# Velocity sequence: ['00289_velocity_51.npy', '00289_velocity_56.npy', '00289_velocity_61.npy', '00289_velocity_66.npy', '00289_velocity_71.npy']
# Thickness sequence: ['00289_thickness_51.npy', '00289_thickness_56.npy', '00289_thickness_61.npy', '00289_thickness_66.npy', '00289_thickness_71.npy']
# Next velocity: 00289_velocity_76.npy
# Next thickness: 00289_thickness_76.npy
#
# Sequence 87:
# Velocity sequence: ['00289_velocity_52.npy', '00289_velocity_57.npy', '00289_velocity_62.npy', '00289_velocity_67.npy', '00289_velocity_72.npy']
# Thickness sequence: ['00289_thickness_52.npy', '00289_thickness_57.npy', '00289_thickness_62.npy', '00289_thickness_67.npy', '00289_thickness_72.npy']
# Next velocity: 00289_velocity_77.npy
# Next thickness: 00289_thickness_77.npy
#
# Sequence 88:
# Velocity sequence: ['00289_velocity_53.npy', '00289_velocity_58.npy', '00289_velocity_63.npy', '00289_velocity_68.npy', '00289_velocity_73.npy']
# Thickness sequence: ['00289_thickness_53.npy', '00289_thickness_58.npy', '00289_thickness_63.npy', '00289_thickness_68.npy', '00289_thickness_73.npy']
# Next velocity: 00289_velocity_78.npy
# Next thickness: 00289_thickness_78.npy
#
# Sequence 89:
# Velocity sequence: ['00289_velocity_54.npy', '00289_velocity_59.npy', '00289_velocity_64.npy', '00289_velocity_69.npy', '00289_velocity_74.npy']
# Thickness sequence: ['00289_thickness_54.npy', '00289_thickness_59.npy', '00289_thickness_64.npy', '00289_thickness_69.npy', '00289_thickness_74.npy']
# Next velocity: 00289_velocity_79.npy
# Next thickness: 00289_thickness_79.npy
#
# Sequence 90:
# Velocity sequence: ['00289_velocity_55.npy', '00289_velocity_60.npy', '00289_velocity_65.npy', '00289_velocity_70.npy', '00289_velocity_75.npy']
# Thickness sequence: ['00289_thickness_55.npy', '00289_thickness_60.npy', '00289_thickness_65.npy', '00289_thickness_70.npy', '00289_thickness_75.npy']
# Next velocity: 00289_velocity_80.npy
# Next thickness: 00289_thickness_80.npy
#
# Sequence 91:
# Velocity sequence: ['00289_velocity_56.npy', '00289_velocity_61.npy', '00289_velocity_66.npy', '00289_velocity_71.npy', '00289_velocity_76.npy']
# Thickness sequence: ['00289_thickness_56.npy', '00289_thickness_61.npy', '00289_thickness_66.npy', '00289_thickness_71.npy', '00289_thickness_76.npy']
# Next velocity: 00289_velocity_81.npy
# Next thickness: 00289_thickness_81.npy
#
# Sequence 92:
# Velocity sequence: ['00289_velocity_57.npy', '00289_velocity_62.npy', '00289_velocity_67.npy', '00289_velocity_72.npy', '00289_velocity_77.npy']
# Thickness sequence: ['00289_thickness_57.npy', '00289_thickness_62.npy', '00289_thickness_67.npy', '00289_thickness_72.npy', '00289_thickness_77.npy']
# Next velocity: 00289_velocity_82.npy
# Next thickness: 00289_thickness_82.npy
#
# Sequence 93:
# Velocity sequence: ['00289_velocity_58.npy', '00289_velocity_63.npy', '00289_velocity_68.npy', '00289_velocity_73.npy', '00289_velocity_78.npy']
# Thickness sequence: ['00289_thickness_58.npy', '00289_thickness_63.npy', '00289_thickness_68.npy', '00289_thickness_73.npy', '00289_thickness_78.npy']
# Next velocity: 00289_velocity_83.npy
# Next thickness: 00289_thickness_83.npy
#
# Sequence 94:
# Velocity sequence: ['00289_velocity_59.npy', '00289_velocity_64.npy', '00289_velocity_69.npy', '00289_velocity_74.npy', '00289_velocity_79.npy']
# Thickness sequence: ['00289_thickness_59.npy', '00289_thickness_64.npy', '00289_thickness_69.npy', '00289_thickness_74.npy', '00289_thickness_79.npy']
# Next velocity: 00289_velocity_84.npy
# Next thickness: 00289_thickness_84.npy
#
# Sequence 95:
# Velocity sequence: ['00289_velocity_60.npy', '00289_velocity_65.npy', '00289_velocity_70.npy', '00289_velocity_75.npy', '00289_velocity_80.npy']
# Thickness sequence: ['00289_thickness_60.npy', '00289_thickness_65.npy', '00289_thickness_70.npy', '00289_thickness_75.npy', '00289_thickness_80.npy']
# Next velocity: 00289_velocity_85.npy
# Next thickness: 00289_thickness_85.npy
#
# Sequence 96:
# Velocity sequence: ['00289_velocity_61.npy', '00289_velocity_66.npy', '00289_velocity_71.npy', '00289_velocity_76.npy', '00289_velocity_81.npy']
# Thickness sequence: ['00289_thickness_61.npy', '00289_thickness_66.npy', '00289_thickness_71.npy', '00289_thickness_76.npy', '00289_thickness_81.npy']
# Next velocity: 00289_velocity_86.npy
# Next thickness: 00289_thickness_86.npy
#
# Sequence 97:
# Velocity sequence: ['00289_velocity_62.npy', '00289_velocity_67.npy', '00289_velocity_72.npy', '00289_velocity_77.npy', '00289_velocity_82.npy']
# Thickness sequence: ['00289_thickness_62.npy', '00289_thickness_67.npy', '00289_thickness_72.npy', '00289_thickness_77.npy', '00289_thickness_82.npy']
# Next velocity: 00289_velocity_87.npy
# Next thickness: 00289_thickness_87.npy
#
# Sequence 98:
# Velocity sequence: ['00289_velocity_63.npy', '00289_velocity_68.npy', '00289_velocity_73.npy', '00289_velocity_78.npy', '00289_velocity_83.npy']
# Thickness sequence: ['00289_thickness_63.npy', '00289_thickness_68.npy', '00289_thickness_73.npy', '00289_thickness_78.npy', '00289_thickness_83.npy']
# Next velocity: 00289_velocity_88.npy
# Next thickness: 00289_thickness_88.npy
#
# Sequence 99:
# Velocity sequence: ['00289_velocity_64.npy', '00289_velocity_69.npy', '00289_velocity_74.npy', '00289_velocity_79.npy', '00289_velocity_84.npy']
# Thickness sequence: ['00289_thickness_64.npy', '00289_thickness_69.npy', '00289_thickness_74.npy', '00289_thickness_79.npy', '00289_thickness_84.npy']
# Next velocity: 00289_velocity_89.npy
# Next thickness: 00289_thickness_89.npy
#
# Sequence 100:
# Velocity sequence: ['00289_velocity_65.npy', '00289_velocity_70.npy', '00289_velocity_75.npy', '00289_velocity_80.npy', '00289_velocity_85.npy']
# Thickness sequence: ['00289_thickness_65.npy', '00289_thickness_70.npy', '00289_thickness_75.npy', '00289_thickness_80.npy', '00289_thickness_85.npy']
# Next velocity: 00289_velocity_90.npy
# Next thickness: 00289_thickness_90.npy
#
# Sequence 101:
# Velocity sequence: ['00289_velocity_66.npy', '00289_velocity_71.npy', '00289_velocity_76.npy', '00289_velocity_81.npy', '00289_velocity_86.npy']
# Thickness sequence: ['00289_thickness_66.npy', '00289_thickness_71.npy', '00289_thickness_76.npy', '00289_thickness_81.npy', '00289_thickness_86.npy']
# Next velocity: 00289_velocity_91.npy
# Next thickness: 00289_thickness_91.npy
#
# Sequence 102:
# Velocity sequence: ['00289_velocity_67.npy', '00289_velocity_72.npy', '00289_velocity_77.npy', '00289_velocity_82.npy', '00289_velocity_87.npy']
# Thickness sequence: ['00289_thickness_67.npy', '00289_thickness_72.npy', '00289_thickness_77.npy', '00289_thickness_82.npy', '00289_thickness_87.npy']
# Next velocity: 00289_velocity_92.npy
# Next thickness: 00289_thickness_92.npy
#
# Sequence 103:
# Velocity sequence: ['00289_velocity_68.npy', '00289_velocity_73.npy', '00289_velocity_78.npy', '00289_velocity_83.npy', '00289_velocity_88.npy']
# Thickness sequence: ['00289_thickness_68.npy', '00289_thickness_73.npy', '00289_thickness_78.npy', '00289_thickness_83.npy', '00289_thickness_88.npy']
# Next velocity: 00289_velocity_93.npy
# Next thickness: 00289_thickness_93.npy
#
# Sequence 104:
# Velocity sequence: ['00289_velocity_69.npy', '00289_velocity_74.npy', '00289_velocity_79.npy', '00289_velocity_84.npy', '00289_velocity_89.npy']
# Thickness sequence: ['00289_thickness_69.npy', '00289_thickness_74.npy', '00289_thickness_79.npy', '00289_thickness_84.npy', '00289_thickness_89.npy']
# Next velocity: 00289_velocity_94.npy
# Next thickness: 00289_thickness_94.npy
#
# Sequence 105:
# Velocity sequence: ['00289_velocity_70.npy', '00289_velocity_75.npy', '00289_velocity_80.npy', '00289_velocity_85.npy', '00289_velocity_90.npy']
# Thickness sequence: ['00289_thickness_70.npy', '00289_thickness_75.npy', '00289_thickness_80.npy', '00289_thickness_85.npy', '00289_thickness_90.npy']
# Next velocity: 00289_velocity_95.npy
# Next thickness: 00289_thickness_95.npy
#
# Sequence 106:
# Velocity sequence: ['00289_velocity_71.npy', '00289_velocity_76.npy', '00289_velocity_81.npy', '00289_velocity_86.npy', '00289_velocity_91.npy']
# Thickness sequence: ['00289_thickness_71.npy', '00289_thickness_76.npy', '00289_thickness_81.npy', '00289_thickness_86.npy', '00289_thickness_91.npy']
# Next velocity: 00289_velocity_96.npy
# Next thickness: 00289_thickness_96.npy
#
# Sequence 107:
# Velocity sequence: ['00289_velocity_72.npy', '00289_velocity_77.npy', '00289_velocity_82.npy', '00289_velocity_87.npy', '00289_velocity_92.npy']
# Thickness sequence: ['00289_thickness_72.npy', '00289_thickness_77.npy', '00289_thickness_82.npy', '00289_thickness_87.npy', '00289_thickness_92.npy']
# Next velocity: 00289_velocity_97.npy
# Next thickness: 00289_thickness_97.npy
#
# Sequence 108:
# Velocity sequence: ['00289_velocity_73.npy', '00289_velocity_78.npy', '00289_velocity_83.npy', '00289_velocity_88.npy', '00289_velocity_93.npy']
# Thickness sequence: ['00289_thickness_73.npy', '00289_thickness_78.npy', '00289_thickness_83.npy', '00289_thickness_88.npy', '00289_thickness_93.npy']
# Next velocity: 00289_velocity_98.npy
# Next thickness: 00289_thickness_98.npy
#
# Sequence 109:
# Velocity sequence: ['00289_velocity_74.npy', '00289_velocity_79.npy', '00289_velocity_84.npy', '00289_velocity_89.npy', '00289_velocity_94.npy']
# Thickness sequence: ['00289_thickness_74.npy', '00289_thickness_79.npy', '00289_thickness_84.npy', '00289_thickness_89.npy', '00289_thickness_94.npy']
# Next velocity: 00289_velocity_99.npy
# Next thickness: 00289_thickness_99.npy
#
# Sequence 110:
# Velocity sequence: ['00289_velocity_75.npy', '00289_velocity_80.npy', '00289_velocity_85.npy', '00289_velocity_90.npy', '00289_velocity_95.npy']
# Thickness sequence: ['00289_thickness_75.npy', '00289_thickness_80.npy', '00289_thickness_85.npy', '00289_thickness_90.npy', '00289_thickness_95.npy']
# Next velocity: 00289_velocity_100.npy
# Next thickness: 00289_thickness_100.npy
#
# Sequence 111:
# Velocity sequence: ['00289_velocity_76.npy', '00289_velocity_81.npy', '00289_velocity_86.npy', '00289_velocity_91.npy', '00289_velocity_96.npy']
# Thickness sequence: ['00289_thickness_76.npy', '00289_thickness_81.npy', '00289_thickness_86.npy', '00289_thickness_91.npy', '00289_thickness_96.npy']
# Next velocity: 00289_velocity_101.npy
# Next thickness: 00289_thickness_101.npy
#
# Sequence 112:
# Velocity sequence: ['00289_velocity_77.npy', '00289_velocity_82.npy', '00289_velocity_87.npy', '00289_velocity_92.npy', '00289_velocity_97.npy']
# Thickness sequence: ['00289_thickness_77.npy', '00289_thickness_82.npy', '00289_thickness_87.npy', '00289_thickness_92.npy', '00289_thickness_97.npy']
# Next velocity: 00289_velocity_102.npy
# Next thickness: 00289_thickness_102.npy
#
# Sequence 113:
# Velocity sequence: ['00289_velocity_78.npy', '00289_velocity_83.npy', '00289_velocity_88.npy', '00289_velocity_93.npy', '00289_velocity_98.npy']
# Thickness sequence: ['00289_thickness_78.npy', '00289_thickness_83.npy', '00289_thickness_88.npy', '00289_thickness_93.npy', '00289_thickness_98.npy']
# Next velocity: 00289_velocity_103.npy
# Next thickness: 00289_thickness_103.npy
#
# Sequence 114:
# Velocity sequence: ['00289_velocity_79.npy', '00289_velocity_84.npy', '00289_velocity_89.npy', '00289_velocity_94.npy', '00289_velocity_99.npy']
# Thickness sequence: ['00289_thickness_79.npy', '00289_thickness_84.npy', '00289_thickness_89.npy', '00289_thickness_94.npy', '00289_thickness_99.npy']
# Next velocity: 00289_velocity_104.npy
# Next thickness: 00289_thickness_104.npy
#
# Sequence 115:
# Velocity sequence: ['00289_velocity_80.npy', '00289_velocity_85.npy', '00289_velocity_90.npy', '00289_velocity_95.npy', '00289_velocity_100.npy']
# Thickness sequence: ['00289_thickness_80.npy', '00289_thickness_85.npy', '00289_thickness_90.npy', '00289_thickness_95.npy', '00289_thickness_100.npy']
# Next velocity: 00289_velocity_105.npy
# Next thickness: 00289_thickness_105.npy
#
# Sequence 116:
# Velocity sequence: ['00289_velocity_81.npy', '00289_velocity_86.npy', '00289_velocity_91.npy', '00289_velocity_96.npy', '00289_velocity_101.npy']
# Thickness sequence: ['00289_thickness_81.npy', '00289_thickness_86.npy', '00289_thickness_91.npy', '00289_thickness_96.npy', '00289_thickness_101.npy']
# Next velocity: 00289_velocity_106.npy
# Next thickness: 00289_thickness_106.npy
#
# Sequence 117:
# Velocity sequence: ['00289_velocity_82.npy', '00289_velocity_87.npy', '00289_velocity_92.npy', '00289_velocity_97.npy', '00289_velocity_102.npy']
# Thickness sequence: ['00289_thickness_82.npy', '00289_thickness_87.npy', '00289_thickness_92.npy', '00289_thickness_97.npy', '00289_thickness_102.npy']
# Next velocity: 00289_velocity_107.npy
# Next thickness: 00289_thickness_107.npy
#
# Sequence 118:
# Velocity sequence: ['00289_velocity_83.npy', '00289_velocity_88.npy', '00289_velocity_93.npy', '00289_velocity_98.npy', '00289_velocity_103.npy']
# Thickness sequence: ['00289_thickness_83.npy', '00289_thickness_88.npy', '00289_thickness_93.npy', '00289_thickness_98.npy', '00289_thickness_103.npy']
# Next velocity: 00289_velocity_108.npy
# Next thickness: 00289_thickness_108.npy
#
# Sequence 119:
# Velocity sequence: ['00289_velocity_84.npy', '00289_velocity_89.npy', '00289_velocity_94.npy', '00289_velocity_99.npy', '00289_velocity_104.npy']
# Thickness sequence: ['00289_thickness_84.npy', '00289_thickness_89.npy', '00289_thickness_94.npy', '00289_thickness_99.npy', '00289_thickness_104.npy']
# Next velocity: 00289_velocity_109.npy
# Next thickness: 00289_thickness_109.npy
#
# Sequence 120:
# Velocity sequence: ['00289_velocity_85.npy', '00289_velocity_90.npy', '00289_velocity_95.npy', '00289_velocity_100.npy', '00289_velocity_105.npy']
# Thickness sequence: ['00289_thickness_85.npy', '00289_thickness_90.npy', '00289_thickness_95.npy', '00289_thickness_100.npy', '00289_thickness_105.npy']
# Next velocity: 00289_velocity_110.npy
# Next thickness: 00289_thickness_110.npy
#
# Sequence 121:
# Velocity sequence: ['00289_velocity_86.npy', '00289_velocity_91.npy', '00289_velocity_96.npy', '00289_velocity_101.npy', '00289_velocity_106.npy']
# Thickness sequence: ['00289_thickness_86.npy', '00289_thickness_91.npy', '00289_thickness_96.npy', '00289_thickness_101.npy', '00289_thickness_106.npy']
# Next velocity: 00289_velocity_111.npy
# Next thickness: 00289_thickness_111.npy
#
# Sequence 122:
# Velocity sequence: ['00289_velocity_87.npy', '00289_velocity_92.npy', '00289_velocity_97.npy', '00289_velocity_102.npy', '00289_velocity_107.npy']
# Thickness sequence: ['00289_thickness_87.npy', '00289_thickness_92.npy', '00289_thickness_97.npy', '00289_thickness_102.npy', '00289_thickness_107.npy']
# Next velocity: 00289_velocity_112.npy
# Next thickness: 00289_thickness_112.npy
#
# Sequence 123:
# Velocity sequence: ['00289_velocity_88.npy', '00289_velocity_93.npy', '00289_velocity_98.npy', '00289_velocity_103.npy', '00289_velocity_108.npy']
# Thickness sequence: ['00289_thickness_88.npy', '00289_thickness_93.npy', '00289_thickness_98.npy', '00289_thickness_103.npy', '00289_thickness_108.npy']
# Next velocity: 00289_velocity_113.npy
# Next thickness: 00289_thickness_113.npy
#
# Sequence 124:
# Velocity sequence: ['00289_velocity_89.npy', '00289_velocity_94.npy', '00289_velocity_99.npy', '00289_velocity_104.npy', '00289_velocity_109.npy']
# Thickness sequence: ['00289_thickness_89.npy', '00289_thickness_94.npy', '00289_thickness_99.npy', '00289_thickness_104.npy', '00289_thickness_109.npy']
# Next velocity: 00289_velocity_114.npy
# Next thickness: 00289_thickness_114.npy
#
# Sequence 125:
# ...
# Thickness sequence: ['00200_thickness_57.npy', '00200_thickness_62.npy', '00200_thickness_67.npy', '00200_thickness_72.npy', '00200_thickness_77.npy']
# Next velocity: 00200_velocity_82.npy
# Next thickness: 00200_thickness_82.npy
#
# Sequence 2054:
# Velocity sequence: ['00200_velocity_58.npy', '00200_velocity_63.npy', '00200_velocity_68.npy', '00200_velocity_73.npy', '00200_velocity_78.npy']
# Thickness sequence: ['00200_thickness_58.npy', '00200_thickness_63.npy', '00200_thickness_68.npy', '00200_thickness_73.npy', '00200_thickness_78.npy']
# Next velocity: 00200_velocity_83.npy
# Next thickness: 00200_thickness_83.npy
#
# Sequence 2055:
# Velocity sequence: ['00200_velocity_59.npy', '00200_velocity_64.npy', '00200_velocity_69.npy', '00200_velocity_74.npy', '00200_velocity_79.npy']
# Thickness sequence: ['00200_thickness_59.npy', '00200_thickness_64.npy', '00200_thickness_69.npy', '00200_thickness_74.npy', '00200_thickness_79.npy']
# Next velocity: 00200_velocity_84.npy
# Next thickness: 00200_thickness_84.npy
#
# Sequence 2056:
# Velocity sequence: ['00200_velocity_60.npy', '00200_velocity_65.npy', '00200_velocity_70.npy', '00200_velocity_75.npy', '00200_velocity_80.npy']
# Thickness sequence: ['00200_thickness_60.npy', '00200_thickness_65.npy', '00200_thickness_70.npy', '00200_thickness_75.npy', '00200_thickness_80.npy']
# Next velocity: 00200_velocity_85.npy
# Next thickness: 00200_thickness_85.npy
#
# Sequence 2057:
# Velocity sequence: ['00200_velocity_61.npy', '00200_velocity_66.npy', '00200_velocity_71.npy', '00200_velocity_76.npy', '00200_velocity_81.npy']
# Thickness sequence: ['00200_thickness_61.npy', '00200_thickness_66.npy', '00200_thickness_71.npy', '00200_thickness_76.npy', '00200_thickness_81.npy']
# Next velocity: 00200_velocity_86.npy
# Next thickness: 00200_thickness_86.npy
#
# Sequence 2058:
# Velocity sequence: ['00200_velocity_62.npy', '00200_velocity_67.npy', '00200_velocity_72.npy', '00200_velocity_77.npy', '00200_velocity_82.npy']
# Thickness sequence: ['00200_thickness_62.npy', '00200_thickness_67.npy', '00200_thickness_72.npy', '00200_thickness_77.npy', '00200_thickness_82.npy']
# Next velocity: 00200_velocity_87.npy
# Next thickness: 00200_thickness_87.npy
#
# Sequence 2059:
# Velocity sequence: ['00200_velocity_63.npy', '00200_velocity_68.npy', '00200_velocity_73.npy', '00200_velocity_78.npy', '00200_velocity_83.npy']
# Thickness sequence: ['00200_thickness_63.npy', '00200_thickness_68.npy', '00200_thickness_73.npy', '00200_thickness_78.npy', '00200_thickness_83.npy']
# Next velocity: 00200_velocity_88.npy
# Next thickness: 00200_thickness_88.npy
#
# Sequence 2060:
# Velocity sequence: ['00200_velocity_64.npy', '00200_velocity_69.npy', '00200_velocity_74.npy', '00200_velocity_79.npy', '00200_velocity_84.npy']
# Thickness sequence: ['00200_thickness_64.npy', '00200_thickness_69.npy', '00200_thickness_74.npy', '00200_thickness_79.npy', '00200_thickness_84.npy']
# Next velocity: 00200_velocity_89.npy
# Next thickness: 00200_thickness_89.npy
#
# Sequence 2061:
# Velocity sequence: ['00200_velocity_65.npy', '00200_velocity_70.npy', '00200_velocity_75.npy', '00200_velocity_80.npy', '00200_velocity_85.npy']
# Thickness sequence: ['00200_thickness_65.npy', '00200_thickness_70.npy', '00200_thickness_75.npy', '00200_thickness_80.npy', '00200_thickness_85.npy']
# Next velocity: 00200_velocity_90.npy
# Next thickness: 00200_thickness_90.npy
#
# Sequence 2062:
# Velocity sequence: ['00200_velocity_66.npy', '00200_velocity_71.npy', '00200_velocity_76.npy', '00200_velocity_81.npy', '00200_velocity_86.npy']
# Thickness sequence: ['00200_thickness_66.npy', '00200_thickness_71.npy', '00200_thickness_76.npy', '00200_thickness_81.npy', '00200_thickness_86.npy']
# Next velocity: 00200_velocity_91.npy
# Next thickness: 00200_thickness_91.npy
#
# Sequence 2063:
# Velocity sequence: ['00200_velocity_67.npy', '00200_velocity_72.npy', '00200_velocity_77.npy', '00200_velocity_82.npy', '00200_velocity_87.npy']
# Thickness sequence: ['00200_thickness_67.npy', '00200_thickness_72.npy', '00200_thickness_77.npy', '00200_thickness_82.npy', '00200_thickness_87.npy']
# Next velocity: 00200_velocity_92.npy
# Next thickness: 00200_thickness_92.npy
#
# Sequence 2064:
# Velocity sequence: ['00200_velocity_68.npy', '00200_velocity_73.npy', '00200_velocity_78.npy', '00200_velocity_83.npy', '00200_velocity_88.npy']
# Thickness sequence: ['00200_thickness_68.npy', '00200_thickness_73.npy', '00200_thickness_78.npy', '00200_thickness_83.npy', '00200_thickness_88.npy']
# Next velocity: 00200_velocity_93.npy
# Next thickness: 00200_thickness_93.npy
#
# Sequence 2065:
# Velocity sequence: ['00200_velocity_69.npy', '00200_velocity_74.npy', '00200_velocity_79.npy', '00200_velocity_84.npy', '00200_velocity_89.npy']
# Thickness sequence: ['00200_thickness_69.npy', '00200_thickness_74.npy', '00200_thickness_79.npy', '00200_thickness_84.npy', '00200_thickness_89.npy']
# Next velocity: 00200_velocity_94.npy
# Next thickness: 00200_thickness_94.npy
#
# Sequence 2066:
# Velocity sequence: ['00200_velocity_70.npy', '00200_velocity_75.npy', '00200_velocity_80.npy', '00200_velocity_85.npy', '00200_velocity_90.npy']
# Thickness sequence: ['00200_thickness_70.npy', '00200_thickness_75.npy', '00200_thickness_80.npy', '00200_thickness_85.npy', '00200_thickness_90.npy']
# Next velocity: 00200_velocity_95.npy
# Next thickness: 00200_thickness_95.npy
#
# Sequence 2067:
# Velocity sequence: ['00200_velocity_71.npy', '00200_velocity_76.npy', '00200_velocity_81.npy', '00200_velocity_86.npy', '00200_velocity_91.npy']
# Thickness sequence: ['00200_thickness_71.npy', '00200_thickness_76.npy', '00200_thickness_81.npy', '00200_thickness_86.npy', '00200_thickness_91.npy']
# Next velocity: 00200_velocity_96.npy
# Next thickness: 00200_thickness_96.npy
#
# Sequence 2068:
# Velocity sequence: ['00200_velocity_72.npy', '00200_velocity_77.npy', '00200_velocity_82.npy', '00200_velocity_87.npy', '00200_velocity_92.npy']
# Thickness sequence: ['00200_thickness_72.npy', '00200_thickness_77.npy', '00200_thickness_82.npy', '00200_thickness_87.npy', '00200_thickness_92.npy']
# Next velocity: 00200_velocity_97.npy
# Next thickness: 00200_thickness_97.npy
#
# Sequence 2069:
# Velocity sequence: ['00200_velocity_73.npy', '00200_velocity_78.npy', '00200_velocity_83.npy', '00200_velocity_88.npy', '00200_velocity_93.npy']
# Thickness sequence: ['00200_thickness_73.npy', '00200_thickness_78.npy', '00200_thickness_83.npy', '00200_thickness_88.npy', '00200_thickness_93.npy']
# Next velocity: 00200_velocity_98.npy
# Next thickness: 00200_thickness_98.npy
#
# Sequence 2070:
# Velocity sequence: ['00200_velocity_74.npy', '00200_velocity_79.npy', '00200_velocity_84.npy', '00200_velocity_89.npy', '00200_velocity_94.npy']
# Thickness sequence: ['00200_thickness_74.npy', '00200_thickness_79.npy', '00200_thickness_84.npy', '00200_thickness_89.npy', '00200_thickness_94.npy']
# Next velocity: 00200_velocity_99.npy
# Next thickness: 00200_thickness_99.npy
#
# Sequence 2071:
# Velocity sequence: ['00200_velocity_75.npy', '00200_velocity_80.npy', '00200_velocity_85.npy', '00200_velocity_90.npy', '00200_velocity_95.npy']
# Thickness sequence: ['00200_thickness_75.npy', '00200_thickness_80.npy', '00200_thickness_85.npy', '00200_thickness_90.npy', '00200_thickness_95.npy']
# Next velocity: 00200_velocity_100.npy
# Next thickness: 00200_thickness_100.npy
#
# Sequence 2072:
# Velocity sequence: ['00200_velocity_76.npy', '00200_velocity_81.npy', '00200_velocity_86.npy', '00200_velocity_91.npy', '00200_velocity_96.npy']
# Thickness sequence: ['00200_thickness_76.npy', '00200_thickness_81.npy', '00200_thickness_86.npy', '00200_thickness_91.npy', '00200_thickness_96.npy']
# Next velocity: 00200_velocity_101.npy
# Next thickness: 00200_thickness_101.npy
#
# Sequence 2073:
# Velocity sequence: ['00200_velocity_77.npy', '00200_velocity_82.npy', '00200_velocity_87.npy', '00200_velocity_92.npy', '00200_velocity_97.npy']
# Thickness sequence: ['00200_thickness_77.npy', '00200_thickness_82.npy', '00200_thickness_87.npy', '00200_thickness_92.npy', '00200_thickness_97.npy']
# Next velocity: 00200_velocity_102.npy
# Next thickness: 00200_thickness_102.npy
#
# Sequence 2074:
# Velocity sequence: ['00200_velocity_78.npy', '00200_velocity_83.npy', '00200_velocity_88.npy', '00200_velocity_93.npy', '00200_velocity_98.npy']
# Thickness sequence: ['00200_thickness_78.npy', '00200_thickness_83.npy', '00200_thickness_88.npy', '00200_thickness_93.npy', '00200_thickness_98.npy']
# Next velocity: 00200_velocity_103.npy
# Next thickness: 00200_thickness_103.npy
#
# Sequence 2075:
# Velocity sequence: ['00200_velocity_79.npy', '00200_velocity_84.npy', '00200_velocity_89.npy', '00200_velocity_94.npy', '00200_velocity_99.npy']
# Thickness sequence: ['00200_thickness_79.npy', '00200_thickness_84.npy', '00200_thickness_89.npy', '00200_thickness_94.npy', '00200_thickness_99.npy']
# Next velocity: 00200_velocity_104.npy
# Next thickness: 00200_thickness_104.npy
#
# Sequence 2076:
# Velocity sequence: ['00200_velocity_80.npy', '00200_velocity_85.npy', '00200_velocity_90.npy', '00200_velocity_95.npy', '00200_velocity_100.npy']
# Thickness sequence: ['00200_thickness_80.npy', '00200_thickness_85.npy', '00200_thickness_90.npy', '00200_thickness_95.npy', '00200_thickness_100.npy']
# Next velocity: 00200_velocity_105.npy
# Next thickness: 00200_thickness_105.npy
#
# Sequence 2077:
# Velocity sequence: ['00200_velocity_81.npy', '00200_velocity_86.npy', '00200_velocity_91.npy', '00200_velocity_96.npy', '00200_velocity_101.npy']
# Thickness sequence: ['00200_thickness_81.npy', '00200_thickness_86.npy', '00200_thickness_91.npy', '00200_thickness_96.npy', '00200_thickness_101.npy']
# Next velocity: 00200_velocity_106.npy
# Next thickness: 00200_thickness_106.npy
#
# Sequence 2078:
# Velocity sequence: ['00200_velocity_82.npy', '00200_velocity_87.npy', '00200_velocity_92.npy', '00200_velocity_97.npy', '00200_velocity_102.npy']
# Thickness sequence: ['00200_thickness_82.npy', '00200_thickness_87.npy', '00200_thickness_92.npy', '00200_thickness_97.npy', '00200_thickness_102.npy']
# Next velocity: 00200_velocity_107.npy
# Next thickness: 00200_thickness_107.npy
#
# Sequence 2079:
# Velocity sequence: ['00200_velocity_83.npy', '00200_velocity_88.npy', '00200_velocity_93.npy', '00200_velocity_98.npy', '00200_velocity_103.npy']
# Thickness sequence: ['00200_thickness_83.npy', '00200_thickness_88.npy', '00200_thickness_93.npy', '00200_thickness_98.npy', '00200_thickness_103.npy']
# Next velocity: 00200_velocity_108.npy
# Next thickness: 00200_thickness_108.npy
#
# Sequence 2080:
# Velocity sequence: ['00200_velocity_84.npy', '00200_velocity_89.npy', '00200_velocity_94.npy', '00200_velocity_99.npy', '00200_velocity_104.npy']
# Thickness sequence: ['00200_thickness_84.npy', '00200_thickness_89.npy', '00200_thickness_94.npy', '00200_thickness_99.npy', '00200_thickness_104.npy']
# Next velocity: 00200_velocity_109.npy
# Next thickness: 00200_thickness_109.npy
#
# Sequence 2081:
# Velocity sequence: ['00200_velocity_85.npy', '00200_velocity_90.npy', '00200_velocity_95.npy', '00200_velocity_100.npy', '00200_velocity_105.npy']
# Thickness sequence: ['00200_thickness_85.npy', '00200_thickness_90.npy', '00200_thickness_95.npy', '00200_thickness_100.npy', '00200_thickness_105.npy']
# Next velocity: 00200_velocity_110.npy
# Next thickness: 00200_thickness_110.npy
#
# Sequence 2082:
# Velocity sequence: ['00200_velocity_86.npy', '00200_velocity_91.npy', '00200_velocity_96.npy', '00200_velocity_101.npy', '00200_velocity_106.npy']
# Thickness sequence: ['00200_thickness_86.npy', '00200_thickness_91.npy', '00200_thickness_96.npy', '00200_thickness_101.npy', '00200_thickness_106.npy']
# Next velocity: 00200_velocity_111.npy
# Next thickness: 00200_thickness_111.npy
#
# Sequence 2083:
# Velocity sequence: ['00200_velocity_87.npy', '00200_velocity_92.npy', '00200_velocity_97.npy', '00200_velocity_102.npy', '00200_velocity_107.npy']
# Thickness sequence: ['00200_thickness_87.npy', '00200_thickness_92.npy', '00200_thickness_97.npy', '00200_thickness_102.npy', '00200_thickness_107.npy']
# Next velocity: 00200_velocity_112.npy
# Next thickness: 00200_thickness_112.npy
#
# Sequence 2084:
# Velocity sequence: ['00200_velocity_88.npy', '00200_velocity_93.npy', '00200_velocity_98.npy', '00200_velocity_103.npy', '00200_velocity_108.npy']
# Thickness sequence: ['00200_thickness_88.npy', '00200_thickness_93.npy', '00200_thickness_98.npy', '00200_thickness_103.npy', '00200_thickness_108.npy']
# Next velocity: 00200_velocity_113.npy
# Next thickness: 00200_thickness_113.npy
#
# Sequence 2085:
# Velocity sequence: ['00200_velocity_89.npy', '00200_velocity_94.npy', '00200_velocity_99.npy', '00200_velocity_104.npy', '00200_velocity_109.npy']
# Thickness sequence: ['00200_thickness_89.npy', '00200_thickness_94.npy', '00200_thickness_99.npy', '00200_thickness_104.npy', '00200_thickness_109.npy']
# Next velocity: 00200_velocity_114.npy
# Next thickness: 00200_thickness_114.npy
#
# Sequence 2086:
# Velocity sequence: ['00200_velocity_90.npy', '00200_velocity_95.npy', '00200_velocity_100.npy', '00200_velocity_105.npy', '00200_velocity_110.npy']
# Thickness sequence: ['00200_thickness_90.npy', '00200_thickness_95.npy', '00200_thickness_100.npy', '00200_thickness_105.npy', '00200_thickness_110.npy']
# Next velocity: 00200_velocity_115.npy
# Next thickness: 00200_thickness_115.npy
#
# Sequence 2087:
# Velocity sequence: ['00200_velocity_91.npy', '00200_velocity_96.npy', '00200_velocity_101.npy', '00200_velocity_106.npy', '00200_velocity_111.npy']
# Thickness sequence: ['00200_thickness_91.npy', '00200_thickness_96.npy', '00200_thickness_101.npy', '00200_thickness_106.npy', '00200_thickness_111.npy']
# Next velocity: 00200_velocity_116.npy
# Next thickness: 00200_thickness_116.npy
#
# Sequence 2088:
# Velocity sequence: ['00200_velocity_92.npy', '00200_velocity_97.npy', '00200_velocity_102.npy', '00200_velocity_107.npy', '00200_velocity_112.npy']
# Thickness sequence: ['00200_thickness_92.npy', '00200_thickness_97.npy', '00200_thickness_102.npy', '00200_thickness_107.npy', '00200_thickness_112.npy']
# Next velocity: 00200_velocity_117.npy
# Next thickness: 00200_thickness_117.npy
#
# Sequence 2089:
# Velocity sequence: ['00200_velocity_93.npy', '00200_velocity_98.npy', '00200_velocity_103.npy', '00200_velocity_108.npy', '00200_velocity_113.npy']
# Thickness sequence: ['00200_thickness_93.npy', '00200_thickness_98.npy', '00200_thickness_103.npy', '00200_thickness_108.npy', '00200_thickness_113.npy']
# Next velocity: 00200_velocity_118.npy
# Next thickness: 00200_thickness_118.npy
#
# Sequence 2090:
# Velocity sequence: ['00200_velocity_94.npy', '00200_velocity_99.npy', '00200_velocity_104.npy', '00200_velocity_109.npy', '00200_velocity_114.npy']
# Thickness sequence: ['00200_thickness_94.npy', '00200_thickness_99.npy', '00200_thickness_104.npy', '00200_thickness_109.npy', '00200_thickness_114.npy']
# Next velocity: 00200_velocity_119.npy
# Next thickness: 00200_thickness_119.npy
#
# Sequence 2091:
# Velocity sequence: ['00200_velocity_95.npy', '00200_velocity_100.npy', '00200_velocity_105.npy', '00200_velocity_110.npy', '00200_velocity_115.npy']
# Thickness sequence: ['00200_thickness_95.npy', '00200_thickness_100.npy', '00200_thickness_105.npy', '00200_thickness_110.npy', '00200_thickness_115.npy']
# Next velocity: 00200_velocity_120.npy
# Next thickness: 00200_thickness_120.npy
#
# Sequence 2092:
# Velocity sequence: ['00200_velocity_96.npy', '00200_velocity_101.npy', '00200_velocity_106.npy', '00200_velocity_111.npy', '00200_velocity_116.npy']
# Thickness sequence: ['00200_thickness_96.npy', '00200_thickness_101.npy', '00200_thickness_106.npy', '00200_thickness_111.npy', '00200_thickness_116.npy']
# Next velocity: 00200_velocity_121.npy
# Next thickness: 00200_thickness_121.npy
#
# Sequence 2093:
# Velocity sequence: ['00200_velocity_97.npy', '00200_velocity_102.npy', '00200_velocity_107.npy', '00200_velocity_112.npy', '00200_velocity_117.npy']
# Thickness sequence: ['00200_thickness_97.npy', '00200_thickness_102.npy', '00200_thickness_107.npy', '00200_thickness_112.npy', '00200_thickness_117.npy']
# Next velocity: 00200_velocity_122.npy
# Next thickness: 00200_thickness_122.npy

# %%
# def compute_min_max(dataset):
#     min_elevation = np.inf
#     max_elevation = -np.inf
#     min_velocity = np.inf
#     max_velocity = -np.inf
#     min_thickness = np.inf
#     max_thickness = -np.inf

#     for input_sequence_data, _ in dataset:
#         elevation = input_sequence_data[:, 0, :, :].numpy()
#         thickness = input_sequence_data[:, 1, :, :].numpy()
#         velocity = input_sequence_data[:, 2, :, :].numpy()

#         min_elevation = min(min_elevation, elevation.min())
#         max_elevation = max(max_elevation, elevation.max())
#         min_velocity = min(min_velocity, velocity.min())
#         max_velocity = max(max_velocity, velocity.max())
#         min_thickness = min(min_thickness, thickness.min())
#         max_thickness = max(max_thickness, thickness.max())

#     return min_elevation, max_elevation, min_velocity, max_velocity, min_thickness, max_thickness

# %%
# # Check the range of values in each dataset
# train_min_max = compute_min_max(train_loader.dataset)
# val_min_max = compute_min_max(val_loader.dataset)
# test_min_max = compute_min_max(test_loader.dataset)

# print("Train dataset range:")
# print("Elevation: [{:.2f}, {:.2f}]".format(*train_min_max[:2]))
# print("Velocity: [{:.2f}, {:.2f}]".format(*train_min_max[2:4]))
# print("Thickness: [{:.2f}, {:.2f}]".format(*train_min_max[4:]))

# print("\nValidation dataset range:")
# print("Elevation: [{:.2f}, {:.2f}]".format(*val_min_max[:2]))
# print("Velocity: [{:.2f}, {:.2f}]".format(*val_min_max[2:4]))
# print("Thickness: [{:.2f}, {:.2f}]".format(*val_min_max[4:]))

# print("\nTest dataset range:")
# print("Elevation: [{:.2f}, {:.2f}]".format(*test_min_max[:2]))
# print("Velocity: [{:.2f}, {:.2f}]".format(*test_min_max[2:4]))
# print("Thickness: [{:.2f}, {:.2f}]".format(*test_min_max[4:]))

# %%
# Model setup

models = [
    {'model': UNetLSTM(input_channels=in_channels, output_channels=out_channels, hidden_size=512), 'name': 'unet_lstm_test_int5_seq5'}
]

# %%
# Set up CUDA
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on device: {device}.")

# Train each model
for model_info in models:
    
    model = model_info['model']

    # Check if multiple GPUs are available and wrap the model using nn.DataParallel
    if torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs!")
        # This will wrap the model for use with multiple GPUs
        model = torch.nn.DataParallel(model)
    
    # Move model to the appropriate device
    model.to(device)
    
    # Define the loss function and optimizer
    # criterion = nn.MSELoss()
    criterion = nn.L1Loss()
    # criterion = CustomDebrisLoss()
    optimizer = Adam(model.parameters(), lr=1e-4)
    
    # Initialize the trainer
    model_name = model_info['name']
    trainer = TrainerSeries(model, optimizer, criterion, device, model_name=model_name, checkpoint_dir=checkpoint_dir)
    
    # Train the model
    print(f"Training {model_name}...")
    trainer.train(train_loader, val_loader, epochs=epochs, checkpoint_interval=5)
    
    print(f"Finished training {model_name}.")
# Out:
# Training on device: cuda.
# Using 2 GPUs!
# Training unet_lstm_test_int5_seq5...
# Epoch [1/50], Loss: 0.2853
# Validation Loss: 0.1387
# Epoch [2/50], Loss: 0.1246
# Validation Loss: 0.1112
# Epoch [3/50], Loss: 0.0900
# Validation Loss: 0.0964
# Epoch [4/50], Loss: 0.0628
# Validation Loss: 0.0256
# Epoch [5/50], Loss: 0.0254
# Validation Loss: 0.0155
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_5.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_5.json
# Epoch [6/50], Loss: 0.0192
# Validation Loss: 0.0132
# Epoch [7/50], Loss: 0.0171
# Validation Loss: 0.0130
# Epoch [8/50], Loss: 0.0165
# Validation Loss: 0.0116
# Epoch [9/50], Loss: 0.0152
# Validation Loss: 0.0112
# Epoch [10/50], Loss: 0.0143
# Validation Loss: 0.0107
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_10.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_10.json
# Epoch [11/50], Loss: 0.0143
# Validation Loss: 0.0103
# Epoch [12/50], Loss: 0.0138
# Validation Loss: 0.0098
# Epoch [13/50], Loss: 0.0130
# Validation Loss: 0.0094
# Epoch [14/50], Loss: 0.0124
# Validation Loss: 0.0089
# Epoch [15/50], Loss: 0.0128
# Validation Loss: 0.0133
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_15.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_15.json
# Epoch [16/50], Loss: 0.0136
# Validation Loss: 0.0092
# Epoch [17/50], Loss: 0.0130
# Validation Loss: 0.0086
# Epoch [18/50], Loss: 0.0118
# Validation Loss: 0.0083
# Epoch [19/50], Loss: 0.0111
# Validation Loss: 0.0080
# Epoch [20/50], Loss: 0.0111
# Validation Loss: 0.0089
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_20.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_20.json
# Epoch [21/50], Loss: 0.0124
# Validation Loss: 0.0087
# Epoch [22/50], Loss: 0.0122
# Validation Loss: 0.0082
# Epoch [23/50], Loss: 0.0111
# Validation Loss: 0.0078
# Epoch [24/50], Loss: 0.0104
# Validation Loss: 0.0073
# Epoch [25/50], Loss: 0.0104
# Validation Loss: 0.0084
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_25.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_25.json
# Epoch [26/50], Loss: 0.0107
# Validation Loss: 0.0074
# Epoch [27/50], Loss: 0.0104
# Validation Loss: 0.0073
# Epoch [28/50], Loss: 0.0102
# Validation Loss: 0.0074
# Epoch [29/50], Loss: 0.0102
# Validation Loss: 0.0068
# Epoch [30/50], Loss: 0.0100
# Validation Loss: 0.0073
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_30.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_30.json
# Epoch [31/50], Loss: 0.0101
# Validation Loss: 0.0068
# Epoch [32/50], Loss: 0.0103
# Validation Loss: 0.0071
# Epoch [33/50], Loss: 0.0099
# Validation Loss: 0.0065
# Epoch [34/50], Loss: 0.0095
# Validation Loss: 0.0068
# Epoch [35/50], Loss: 0.0108
# Validation Loss: 0.0070
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_35.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_35.json
# Epoch [36/50], Loss: 0.0096
# Validation Loss: 0.0063
# Epoch [37/50], Loss: 0.0092
# Validation Loss: 0.0061
# Epoch [38/50], Loss: 0.0089
# Validation Loss: 0.0068
# Epoch [39/50], Loss: 0.0106
# Validation Loss: 0.0082
# Epoch [40/50], Loss: 0.0098
# Validation Loss: 0.0063
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_40.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_40.json
# Epoch [41/50], Loss: 0.0086
# Validation Loss: 0.0063
# Epoch [42/50], Loss: 0.0090
# Validation Loss: 0.0061
# Epoch [43/50], Loss: 0.0089
# Validation Loss: 0.0073
# Epoch [44/50], Loss: 0.0094
# Validation Loss: 0.0062
# Epoch [45/50], Loss: 0.0089
# Validation Loss: 0.0058
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_45.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_45.json
# Epoch [46/50], Loss: 0.0084
# Validation Loss: 0.0062
# Epoch [47/50], Loss: 0.0099
# Validation Loss: 0.0060
# Epoch [48/50], Loss: 0.0088
# Validation Loss: 0.0058
# Epoch [49/50], Loss: 0.0084
# Validation Loss: 0.0059
# Epoch [50/50], Loss: 0.0088
# Validation Loss: 0.0068
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_50.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_50.json
# Model saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/model_epoch_50.pth
# Losses saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/losses_epoch_50.json
# Loss plot saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/loss_plot.png
# Finished training unet_lstm_test_int5_seq5.

# %%
# Evaluate the model on the test set
print("Plotting losses...")
trainer.plot_losses()
# Out:
# Plotting losses...
# Loss plot saved to /home/tom/repos/dyna-landslide-surrogate/checkpoints/unet_lstm_test_int5_seq5/loss_plot.png

# %%
# Evaluate the model on the test set
print("Evaluating the model on the test set...")
trainer.test(test_loader)
# Out:
# Evaluating the model on the test set...
# Test Loss: 0.0126

# %%
trainer.scaling_factors
# Out:
# (0.0, 267.08, 0.0, 30.0, 0.0, 8.0)

# %%
trainer.sequence_length
# Out:
# 5

# %%
model_number = '00015'
state_number = 2
num_timesteps = 3


input_tensor = trainer.create_inference_input(root_dir=root_dir, 
                                              model_number=model_number, 
                                              state_number=state_number, 
                                              array_size=256)

# %%
input_tensor.shape
# Out:
# torch.Size([3, 256, 256])

# %%
inferred = trainer.infer(input_tensor, num_timesteps=num_timesteps)
# Out:
# Initial sequence shape: torch.Size([3, 256, 256])
# Initial sequence device: cuda:0
# Elevation shape: torch.Size([1, 256, 256])
# Input tensor length: 5
#
# Timestep: 0
# Input sequence shape: torch.Size([1, 5, 3, 256, 256])
# Next state shape: torch.Size([1, 2, 256, 256])
# Inferred state shape at timestep 1: (2, 256, 256)
# Next state with elevation shape: torch.Size([3, 256, 256])
# Input tensor length after updating: 5
#
# Timestep: 1
# Input sequence shape: torch.Size([1, 5, 3, 256, 256])
# Next state shape: torch.Size([1, 2, 256, 256])
# Inferred state shape at timestep 2: (2, 256, 256)
# Next state with elevation shape: torch.Size([3, 256, 256])
# Input tensor length after updating: 5
#
# Timestep: 2
# Input sequence shape: torch.Size([1, 5, 3, 256, 256])
# Next state shape: torch.Size([1, 2, 256, 256])
# Inferred state shape at timestep 3: (2, 256, 256)
# Next state with elevation shape: torch.Size([3, 256, 256])
# Input tensor length after updating: 5
#
# Final inferred states: [1, 2, 3]
#
# Comparison of inferred states:
# Timestep 1 vs Timestep 2:
#   Mean Squared Error (MSE): 0.0000
#   Mean Absolute Error (MAE): 0.0006
# Timestep 1 vs Timestep 3:
#   Mean Squared Error (MSE): 0.0001
#   Mean Absolute Error (MAE): 0.0007
# Timestep 2 vs Timestep 3:
#   Mean Squared Error (MSE): 0.0000
#   Mean Absolute Error (MAE): 0.0001

# %%
# Get all keys from the dictionary
keys = inferred.keys()

# Print the keys
print(keys)

# If you want to use the keys as a list (for indexing or other list-specific operations), you can convert it to a list:
keys_list = list(keys)
print(keys_list)
# Out:
# dict_keys([1, 2, 3])
# [1, 2, 3]

# %%
for key, value in inferred.items():
    print(f"Key: {key} -> Type of value: {type(value).__name__}")
# Out:
# Key: 1 -> Type of value: ndarray
# Key: 2 -> Type of value: ndarray
# Key: 3 -> Type of value: ndarray

# %%
inferred[keys_list[1]].shape
# Out:
# (2, 256, 256)

# %%
# Plot the expected vs predicted results
print("Plotting the expected vs predicted results...")
trainer.plot_predictions(test_loader, num_predictions=10)
# Out:
# Plotting the expected vs predicted results...
