# %%
import os
import numpy as np

# Paths
source_dir = '/home/tom/repos/dyna-landslide-surrogate/data_prune'

# Function to calculate the percentage of zeros in a numpy array
def calculate_zero_percentage(npy_file):
    array = np.load(npy_file)
    total_elements = array.size
    zero_count = np.count_nonzero(array == 0)
    zero_percentage = (zero_count / total_elements) * 100
    return zero_percentage

# Function to process files in a specified subdirectory (either 'thickness' or 'velocity')
def process_data_type(model_id, data_type):
    data_path = os.path.join(source_dir, model_id, '04_FinalProcessedData_256', data_type)
    zero_percentages = []
    if os.path.isdir(data_path):
        print(f"Processing {data_type} for model_id: {model_id}")
        for filename in os.listdir(data_path):
            if filename.endswith('.npy'):
                file_path = os.path.join(data_path, filename)
                zero_percentage = calculate_zero_percentage(file_path)
                zero_percentages.append(zero_percentage)
                print(f"{filename}: {zero_percentage:.2f}% of the array cells are zero.")
        if zero_percentages:
            avg_zero_percentage = sum(zero_percentages) / len(zero_percentages)
            print(f"Average sparseness for {data_type} in model {model_id}: {avg_zero_percentage:.2f}%")
    else:
        print(f"No {data_type} directory found for model_id: {model_id}")

# Iterate over each model_id directory in the source directory
for model_id in os.listdir(source_dir):
    if os.path.isdir(os.path.join(source_dir, model_id)):
        # Process thickness and velocity data
        process_data_type(model_id, 'thickness')
        process_data_type(model_id, 'velocity')
# Out:
# Processing thickness for model_id: 00192
# 00192_thickness_24.npy: 99.78% of the array cells are zero.
# 00192_thickness_27.npy: 99.76% of the array cells are zero.
# 00192_thickness_47.npy: 99.82% of the array cells are zero.
# 00192_thickness_6.npy: 99.94% of the array cells are zero.
# 00192_thickness_33.npy: 99.75% of the array cells are zero.
# 00192_thickness_25.npy: 99.77% of the array cells are zero.
# 00192_thickness_38.npy: 99.78% of the array cells are zero.
# 00192_thickness_20.npy: 99.77% of the array cells are zero.
# 00192_thickness_2.npy: 99.96% of the array cells are zero.
# 00192_thickness_18.npy: 99.76% of the array cells are zero.
# 00192_thickness_8.npy: 99.91% of the array cells are zero.
# 00192_thickness_40.npy: 99.79% of the array cells are zero.
# 00192_thickness_42.npy: 99.79% of the array cells are zero.
# 00192_thickness_49.npy: 99.83% of the array cells are zero.
# 00192_thickness_39.npy: 99.78% of the array cells are zero.
# 00192_thickness_28.npy: 99.76% of the array cells are zero.
# 00192_thickness_26.npy: 99.77% of the array cells are zero.
# 00192_thickness_46.npy: 99.82% of the array cells are zero.
# 00192_thickness_36.npy: 99.77% of the array cells are zero.
# 00192_thickness_15.npy: 99.73% of the array cells are zero.
# 00192_thickness_45.npy: 99.81% of the array cells are zero.
# 00192_thickness_37.npy: 99.78% of the array cells are zero.
# 00192_thickness_3.npy: 99.96% of the array cells are zero.
# 00192_thickness_19.npy: 99.77% of the array cells are zero.
# 00192_thickness_34.npy: 99.76% of the array cells are zero.
# 00192_thickness_32.npy: 99.75% of the array cells are zero.
# 00192_thickness_10.npy: 99.86% of the array cells are zero.
# 00192_thickness_41.npy: 99.78% of the array cells are zero.
# 00192_thickness_7.npy: 99.93% of the array cells are zero.
# 00192_thickness_43.npy: 99.79% of the array cells are zero.
# 00192_thickness_11.npy: 99.83% of the array cells are zero.
# 00192_thickness_13.npy: 99.77% of the array cells are zero.
# 00192_thickness_4.npy: 99.94% of the array cells are zero.
# 00192_thickness_21.npy: 99.77% of the array cells are zero.
# 00192_thickness_30.npy: 99.76% of the array cells are zero.
# 00192_thickness_17.npy: 99.75% of the array cells are zero.
# 00192_thickness_14.npy: 99.75% of the array cells are zero.
# 00192_thickness_50.npy: 99.83% of the array cells are zero.
# 00192_thickness_48.npy: 99.82% of the array cells are zero.
# 00192_thickness_5.npy: 99.94% of the array cells are zero.
# 00192_thickness_31.npy: 99.74% of the array cells are zero.
# 00192_thickness_44.npy: 99.80% of the array cells are zero.
# 00192_thickness_23.npy: 99.77% of the array cells are zero.
# 00192_thickness_35.npy: 99.76% of the array cells are zero.
# 00192_thickness_22.npy: 99.78% of the array cells are zero.
# 00192_thickness_9.npy: 99.89% of the array cells are zero.
# 00192_thickness_16.npy: 99.73% of the array cells are zero.
# 00192_thickness_29.npy: 99.77% of the array cells are zero.
# 00192_thickness_12.npy: 99.80% of the array cells are zero.
# Average sparseness for thickness in model 00192: 99.81%
# Processing velocity for model_id: 00192
# 00192_velocity_27.npy: 99.52% of the array cells are zero.
# 00192_velocity_42.npy: 99.66% of the array cells are zero.
# 00192_velocity_33.npy: 99.56% of the array cells are zero.
# 00192_velocity_44.npy: 99.69% of the array cells are zero.
# 00192_velocity_34.npy: 99.58% of the array cells are zero.
# 00192_velocity_48.npy: 99.73% of the array cells are zero.
# 00192_velocity_47.npy: 99.71% of the array cells are zero.
# 00192_velocity_28.npy: 99.51% of the array cells are zero.
# 00192_velocity_35.npy: 99.60% of the array cells are zero.
# 00192_velocity_19.npy: 99.57% of the array cells are zero.
# 00192_velocity_12.npy: 99.72% of the array cells are zero.
# 00192_velocity_8.npy: 99.87% of the array cells are zero.
# 00192_velocity_41.npy: 99.66% of the array cells are zero.
# 00192_velocity_3.npy: 99.90% of the array cells are zero.
# 00192_velocity_15.npy: 99.62% of the array cells are zero.
# 00192_velocity_32.npy: 99.54% of the array cells are zero.
# 00192_velocity_20.npy: 99.55% of the array cells are zero.
# 00192_velocity_10.npy: 99.80% of the array cells are zero.
# 00192_velocity_50.npy: 99.75% of the array cells are zero.
# 00192_velocity_13.npy: 99.70% of the array cells are zero.
# 00192_velocity_40.npy: 99.66% of the array cells are zero.
# 00192_velocity_23.npy: 99.54% of the array cells are zero.
# 00192_velocity_24.npy: 99.52% of the array cells are zero.
# 00192_velocity_5.npy: 99.90% of the array cells are zero.
# 00192_velocity_31.npy: 99.51% of the array cells are zero.
# 00192_velocity_30.npy: 99.51% of the array cells are zero.
# 00192_velocity_43.npy: 99.66% of the array cells are zero.
# 00192_velocity_11.npy: 99.77% of the array cells are zero.
# 00192_velocity_18.npy: 99.57% of the array cells are zero.
# 00192_velocity_9.npy: 99.84% of the array cells are zero.
# 00192_velocity_17.npy: 99.58% of the array cells are zero.
# 00192_velocity_4.npy: 99.90% of the array cells are zero.
# 00192_velocity_38.npy: 99.64% of the array cells are zero.
# 00192_velocity_21.npy: 99.55% of the array cells are zero.
# 00192_velocity_29.npy: 99.53% of the array cells are zero.
# 00192_velocity_16.npy: 99.58% of the array cells are zero.
# 00192_velocity_49.npy: 99.74% of the array cells are zero.
# 00192_velocity_26.npy: 99.52% of the array cells are zero.
# 00192_velocity_14.npy: 99.66% of the array cells are zero.
# 00192_velocity_36.npy: 99.60% of the array cells are zero.
# 00192_velocity_25.npy: 99.53% of the array cells are zero.
# 00192_velocity_2.npy: 100.00% of the array cells are zero.
# 00192_velocity_39.npy: 99.64% of the array cells are zero.
# 00192_velocity_45.npy: 99.70% of the array cells are zero.
# 00192_velocity_22.npy: 99.55% of the array cells are zero.
# 00192_velocity_7.npy: 99.90% of the array cells are zero.
# 00192_velocity_46.npy: 99.71% of the array cells are zero.
# 00192_velocity_6.npy: 99.90% of the array cells are zero.
# 00192_velocity_37.npy: 99.62% of the array cells are zero.
# Average sparseness for velocity in model 00192: 99.67%
# Processing thickness for model_id: 00158
# 00158_thickness_63.npy: 99.33% of the array cells are zero.
# 00158_thickness_68.npy: 99.38% of the array cells are zero.
# 00158_thickness_106.npy: 99.64% of the array cells are zero.
# 00158_thickness_108.npy: 99.65% of the array cells are zero.
# 00158_thickness_98.npy: 99.53% of the array cells are zero.
# 00158_thickness_60.npy: 99.35% of the array cells are zero.
# 00158_thickness_85.npy: 99.42% of the array cells are zero.
# 00158_thickness_104.npy: 99.61% of the array cells are zero.
# 00158_thickness_35.npy: 99.70% of the array cells are zero.
# 00158_thickness_30.npy: 99.72% of the array cells are zero.
# 00158_thickness_107.npy: 99.65% of the array cells are zero.
# 00158_thickness_71.npy: 99.38% of the array cells are zero.
# 00158_thickness_110.npy: 99.66% of the array cells are zero.
# 00158_thickness_74.npy: 99.38% of the array cells are zero.
# 00158_thickness_39.npy: 99.67% of the array cells are zero.
# 00158_thickness_12.npy: 99.71% of the array cells are zero.
# 00158_thickness_2.npy: 99.90% of the array cells are zero.
# 00158_thickness_100.npy: 99.52% of the array cells are zero.
# 00158_thickness_78.npy: 99.37% of the array cells are zero.
# 00158_thickness_84.npy: 99.43% of the array cells are zero.
# 00158_thickness_45.npy: 99.61% of the array cells are zero.
# 00158_thickness_91.npy: 99.44% of the array cells are zero.
# 00158_thickness_81.npy: 99.39% of the array cells are zero.
# 00158_thickness_94.npy: 99.47% of the array cells are zero.
# 00158_thickness_52.npy: 99.48% of the array cells are zero.
# 00158_thickness_11.npy: 99.74% of the array cells are zero.
# 00158_thickness_25.npy: 99.75% of the array cells are zero.
# 00158_thickness_101.npy: 99.54% of the array cells are zero.
# 00158_thickness_97.npy: 99.53% of the array cells are zero.
# 00158_thickness_22.npy: 99.69% of the array cells are zero.
# 00158_thickness_75.npy: 99.34% of the array cells are zero.
# 00158_thickness_93.npy: 99.48% of the array cells are zero.
# 00158_thickness_49.npy: 99.53% of the array cells are zero.
# 00158_thickness_16.npy: 99.69% of the array cells are zero.
# 00158_thickness_89.npy: 99.45% of the array cells are zero.
# 00158_thickness_36.npy: 99.69% of the array cells are zero.
# 00158_thickness_95.npy: 99.51% of the array cells are zero.
# 00158_thickness_86.npy: 99.41% of the array cells are zero.
# 00158_thickness_87.npy: 99.42% of the array cells are zero.
# 00158_thickness_76.npy: 99.38% of the array cells are zero.
# 00158_thickness_58.npy: 99.38% of the array cells are zero.
# 00158_thickness_55.npy: 99.42% of the array cells are zero.
# 00158_thickness_105.npy: 99.64% of the array cells are zero.
# 00158_thickness_28.npy: 99.74% of the array cells are zero.
# 00158_thickness_50.npy: 99.52% of the array cells are zero.
# 00158_thickness_79.npy: 99.36% of the array cells are zero.
# 00158_thickness_53.npy: 99.46% of the array cells are zero.
# 00158_thickness_103.npy: 99.58% of the array cells are zero.
# 00158_thickness_109.npy: 99.65% of the array cells are zero.
# 00158_thickness_59.npy: 99.35% of the array cells are zero.
# 00158_thickness_61.npy: 99.33% of the array cells are zero.
# 00158_thickness_13.npy: 99.71% of the array cells are zero.
# 00158_thickness_31.npy: 99.73% of the array cells are zero.
# 00158_thickness_4.npy: 99.89% of the array cells are zero.
# 00158_thickness_19.npy: 99.67% of the array cells are zero.
# 00158_thickness_32.npy: 99.73% of the array cells are zero.
# 00158_thickness_8.npy: 99.83% of the array cells are zero.
# 00158_thickness_64.npy: 99.37% of the array cells are zero.
# 00158_thickness_57.npy: 99.39% of the array cells are zero.
# 00158_thickness_21.npy: 99.67% of the array cells are zero.
# 00158_thickness_37.npy: 99.69% of the array cells are zero.
# 00158_thickness_96.npy: 99.51% of the array cells are zero.
# 00158_thickness_26.npy: 99.77% of the array cells are zero.
# 00158_thickness_18.npy: 99.67% of the array cells are zero.
# 00158_thickness_51.npy: 99.50% of the array cells are zero.
# 00158_thickness_82.npy: 99.42% of the array cells are zero.
# 00158_thickness_15.npy: 99.69% of the array cells are zero.
# 00158_thickness_83.npy: 99.39% of the array cells are zero.
# 00158_thickness_29.npy: 99.73% of the array cells are zero.
# 00158_thickness_67.npy: 99.36% of the array cells are zero.
# 00158_thickness_38.npy: 99.69% of the array cells are zero.
# 00158_thickness_90.npy: 99.44% of the array cells are zero.
# 00158_thickness_62.npy: 99.35% of the array cells are zero.
# 00158_thickness_92.npy: 99.44% of the array cells are zero.
# 00158_thickness_3.npy: 99.90% of the array cells are zero.
# 00158_thickness_20.npy: 99.67% of the array cells are zero.
# 00158_thickness_66.npy: 99.37% of the array cells are zero.
# 00158_thickness_102.npy: 99.57% of the array cells are zero.
# 00158_thickness_70.npy: 99.36% of the array cells are zero.
# 00158_thickness_7.npy: 99.84% of the array cells are zero.
# 00158_thickness_40.npy: 99.67% of the array cells are zero.
# 00158_thickness_9.npy: 99.78% of the array cells are zero.
# 00158_thickness_73.npy: 99.36% of the array cells are zero.
# 00158_thickness_23.npy: 99.71% of the array cells are zero.
# 00158_thickness_65.npy: 99.35% of the array cells are zero.
# 00158_thickness_42.npy: 99.64% of the array cells are zero.
# 00158_thickness_33.npy: 99.73% of the array cells are zero.
# 00158_thickness_56.npy: 99.42% of the array cells are zero.
# 00158_thickness_88.npy: 99.42% of the array cells are zero.
# 00158_thickness_44.npy: 99.62% of the array cells are zero.
# 00158_thickness_24.npy: 99.74% of the array cells are zero.
# 00158_thickness_17.npy: 99.69% of the array cells are zero.
# 00158_thickness_80.npy: 99.37% of the array cells are zero.
# 00158_thickness_5.npy: 99.88% of the array cells are zero.
# 00158_thickness_69.npy: 99.36% of the array cells are zero.
# 00158_thickness_27.npy: 99.75% of the array cells are zero.
# 00158_thickness_14.npy: 99.71% of the array cells are zero.
# 00158_thickness_77.npy: 99.37% of the array cells are zero.
# 00158_thickness_43.npy: 99.64% of the array cells are zero.
# 00158_thickness_46.npy: 99.60% of the array cells are zero.
# 00158_thickness_99.npy: 99.52% of the array cells are zero.
# 00158_thickness_10.npy: 99.75% of the array cells are zero.
# 00158_thickness_34.npy: 99.71% of the array cells are zero.
# 00158_thickness_47.npy: 99.58% of the array cells are zero.
# 00158_thickness_41.npy: 99.66% of the array cells are zero.
# 00158_thickness_6.npy: 99.88% of the array cells are zero.
# 00158_thickness_72.npy: 99.37% of the array cells are zero.
# 00158_thickness_54.npy: 99.44% of the array cells are zero.
# 00158_thickness_48.npy: 99.56% of the array cells are zero.
# Average sparseness for thickness in model 00158: 99.57%
# Processing velocity for model_id: 00158
# 00158_velocity_100.npy: 98.99% of the array cells are zero.
# 00158_velocity_92.npy: 98.81% of the array cells are zero.
# 00158_velocity_70.npy: 98.50% of the array cells are zero.
# 00158_velocity_84.npy: 98.73% of the array cells are zero.
# 00158_velocity_106.npy: 99.24% of the array cells are zero.
# 00158_velocity_53.npy: 98.91% of the array cells are zero.
# 00158_velocity_77.npy: 98.58% of the array cells are zero.
# 00158_velocity_17.npy: 99.41% of the array cells are zero.
# 00158_velocity_96.npy: 98.86% of the array cells are zero.
# 00158_velocity_90.npy: 98.77% of the array cells are zero.
# 00158_velocity_68.npy: 98.53% of the array cells are zero.
# 00158_velocity_57.npy: 98.77% of the array cells are zero.
# 00158_velocity_80.npy: 98.54% of the array cells are zero.
# 00158_velocity_33.npy: 99.48% of the array cells are zero.
# 00158_velocity_55.npy: 98.82% of the array cells are zero.
# 00158_velocity_103.npy: 99.11% of the array cells are zero.
# 00158_velocity_31.npy: 99.49% of the array cells are zero.
# 00158_velocity_21.npy: 99.38% of the array cells are zero.
# 00158_velocity_37.npy: 99.38% of the array cells are zero.
# 00158_velocity_59.npy: 98.70% of the array cells are zero.
# 00158_velocity_50.npy: 98.97% of the array cells are zero.
# 00158_velocity_93.npy: 98.85% of the array cells are zero.
# 00158_velocity_72.npy: 98.55% of the array cells are zero.
# 00158_velocity_67.npy: 98.50% of the array cells are zero.
# 00158_velocity_91.npy: 98.79% of the array cells are zero.
# 00158_velocity_7.npy: 99.67% of the array cells are zero.
# 00158_velocity_45.npy: 99.17% of the array cells are zero.
# 00158_velocity_66.npy: 98.47% of the array cells are zero.
# 00158_velocity_73.npy: 98.55% of the array cells are zero.
# 00158_velocity_58.npy: 98.71% of the array cells are zero.
# 00158_velocity_60.npy: 98.65% of the array cells are zero.
# 00158_velocity_52.npy: 98.96% of the array cells are zero.
# 00158_velocity_44.npy: 99.22% of the array cells are zero.
# 00158_velocity_110.npy: 99.30% of the array cells are zero.
# 00158_velocity_12.npy: 99.41% of the array cells are zero.
# 00158_velocity_83.npy: 98.69% of the array cells are zero.
# 00158_velocity_86.npy: 98.76% of the array cells are zero.
# 00158_velocity_35.npy: 99.40% of the array cells are zero.
# 00158_velocity_56.npy: 98.77% of the array cells are zero.
# 00158_velocity_26.npy: 99.52% of the array cells are zero.
# 00158_velocity_23.npy: 99.42% of the array cells are zero.
# 00158_velocity_41.npy: 99.31% of the array cells are zero.
# 00158_velocity_13.npy: 99.43% of the array cells are zero.
# 00158_velocity_2.npy: 100.00% of the array cells are zero.
# 00158_velocity_101.npy: 99.04% of the array cells are zero.
# 00158_velocity_105.npy: 99.21% of the array cells are zero.
# 00158_velocity_107.npy: 99.28% of the array cells are zero.
# 00158_velocity_22.npy: 99.39% of the array cells are zero.
# 00158_velocity_94.npy: 98.86% of the array cells are zero.
# 00158_velocity_25.npy: 99.52% of the array cells are zero.
# 00158_velocity_69.npy: 98.50% of the array cells are zero.
# 00158_velocity_24.npy: 99.48% of the array cells are zero.
# 00158_velocity_18.npy: 99.40% of the array cells are zero.
# 00158_velocity_51.npy: 98.98% of the array cells are zero.
# 00158_velocity_98.npy: 98.91% of the array cells are zero.
# 00158_velocity_62.npy: 98.60% of the array cells are zero.
# 00158_velocity_39.npy: 99.38% of the array cells are zero.
# 00158_velocity_65.npy: 98.54% of the array cells are zero.
# 00158_velocity_29.npy: 99.49% of the array cells are zero.
# 00158_velocity_89.npy: 98.72% of the array cells are zero.
# 00158_velocity_54.npy: 98.85% of the array cells are zero.
# 00158_velocity_28.npy: 99.49% of the array cells are zero.
# 00158_velocity_19.npy: 99.40% of the array cells are zero.
# 00158_velocity_76.npy: 98.54% of the array cells are zero.
# 00158_velocity_15.npy: 99.41% of the array cells are zero.
# 00158_velocity_42.npy: 99.28% of the array cells are zero.
# 00158_velocity_20.npy: 99.37% of the array cells are zero.
# 00158_velocity_61.npy: 98.61% of the array cells are zero.
# 00158_velocity_46.npy: 99.13% of the array cells are zero.
# 00158_velocity_95.npy: 98.83% of the array cells are zero.
# 00158_velocity_14.npy: 99.41% of the array cells are zero.
# 00158_velocity_109.npy: 99.30% of the array cells are zero.
# 00158_velocity_78.npy: 98.55% of the array cells are zero.
# 00158_velocity_8.npy: 99.66% of the array cells are zero.
# 00158_velocity_48.npy: 99.08% of the array cells are zero.
# 00158_velocity_87.npy: 98.79% of the array cells are zero.
# 00158_velocity_63.npy: 98.57% of the array cells are zero.
# 00158_velocity_32.npy: 99.50% of the array cells are zero.
# 00158_velocity_40.npy: 99.33% of the array cells are zero.
# 00158_velocity_97.npy: 98.89% of the array cells are zero.
# 00158_velocity_5.npy: 99.65% of the array cells are zero.
# 00158_velocity_85.npy: 98.69% of the array cells are zero.
# 00158_velocity_82.npy: 98.58% of the array cells are zero.
# 00158_velocity_9.npy: 99.57% of the array cells are zero.
# 00158_velocity_30.npy: 99.49% of the array cells are zero.
# 00158_velocity_102.npy: 99.07% of the array cells are zero.
# 00158_velocity_38.npy: 99.38% of the array cells are zero.
# 00158_velocity_3.npy: 99.65% of the array cells are zero.
# 00158_velocity_11.npy: 99.49% of the array cells are zero.
# 00158_velocity_43.npy: 99.23% of the array cells are zero.
# 00158_velocity_75.npy: 98.50% of the array cells are zero.
# 00158_velocity_6.npy: 99.65% of the array cells are zero.
# 00158_velocity_74.npy: 98.57% of the array cells are zero.
# 00158_velocity_49.npy: 99.02% of the array cells are zero.
# 00158_velocity_47.npy: 99.08% of the array cells are zero.
# 00158_velocity_36.npy: 99.40% of the array cells are zero.
# 00158_velocity_71.npy: 98.55% of the array cells are zero.
# 00158_velocity_88.npy: 98.77% of the array cells are zero.
# 00158_velocity_64.npy: 98.50% of the array cells are zero.
# 00158_velocity_16.npy: 99.40% of the array cells are zero.
# 00158_velocity_4.npy: 99.67% of the array cells are zero.
# 00158_velocity_81.npy: 98.57% of the array cells are zero.
# 00158_velocity_104.npy: 99.18% of the array cells are zero.
# 00158_velocity_34.npy: 99.44% of the array cells are zero.
# 00158_velocity_10.npy: 99.49% of the array cells are zero.
# 00158_velocity_27.npy: 99.49% of the array cells are zero.
# 00158_velocity_79.npy: 98.61% of the array cells are zero.
# 00158_velocity_108.npy: 99.30% of the array cells are zero.
# 00158_velocity_99.npy: 98.90% of the array cells are zero.
# Average sparseness for velocity in model 00158: 99.07%
# Processing thickness for model_id: 00055
# 00055_thickness_13.npy: 99.67% of the array cells are zero.
# 00055_thickness_41.npy: 99.67% of the array cells are zero.
# 00055_thickness_30.npy: 99.62% of the array cells are zero.
# 00055_thickness_21.npy: 99.54% of the array cells are zero.
# 00055_thickness_7.npy: 99.84% of the array cells are zero.
# 00055_thickness_4.npy: 99.92% of the array cells are zero.
# 00055_thickness_23.npy: 99.56% of the array cells are zero.
# 00055_thickness_36.npy: 99.63% of the array cells are zero.
# 00055_thickness_37.npy: 99.65% of the array cells are zero.
# 00055_thickness_22.npy: 99.53% of the array cells are zero.
# 00055_thickness_3.npy: 99.92% of the array cells are zero.
# 00055_thickness_2.npy: 99.95% of the array cells are zero.
# 00055_thickness_25.npy: 99.58% of the array cells are zero.
# 00055_thickness_17.npy: 99.61% of the array cells are zero.
# 00055_thickness_31.npy: 99.63% of the array cells are zero.
# 00055_thickness_29.npy: 99.58% of the array cells are zero.
# 00055_thickness_43.npy: 99.69% of the array cells are zero.
# 00055_thickness_12.npy: 99.70% of the array cells are zero.
# 00055_thickness_16.npy: 99.60% of the array cells are zero.
# 00055_thickness_38.npy: 99.66% of the array cells are zero.
# 00055_thickness_8.npy: 99.82% of the array cells are zero.
# 00055_thickness_35.npy: 99.63% of the array cells are zero.
# 00055_thickness_26.npy: 99.58% of the array cells are zero.
# 00055_thickness_10.npy: 99.76% of the array cells are zero.
# 00055_thickness_34.npy: 99.62% of the array cells are zero.
# 00055_thickness_40.npy: 99.66% of the array cells are zero.
# 00055_thickness_33.npy: 99.63% of the array cells are zero.
# 00055_thickness_18.npy: 99.60% of the array cells are zero.
# 00055_thickness_44.npy: 99.70% of the array cells are zero.
# 00055_thickness_27.npy: 99.57% of the array cells are zero.
# 00055_thickness_20.npy: 99.53% of the array cells are zero.
# 00055_thickness_32.npy: 99.64% of the array cells are zero.
# 00055_thickness_9.npy: 99.79% of the array cells are zero.
# 00055_thickness_19.npy: 99.57% of the array cells are zero.
# 00055_thickness_42.npy: 99.68% of the array cells are zero.
# 00055_thickness_6.npy: 99.88% of the array cells are zero.
# 00055_thickness_39.npy: 99.66% of the array cells are zero.
# 00055_thickness_15.npy: 99.63% of the array cells are zero.
# 00055_thickness_5.npy: 99.90% of the array cells are zero.
# 00055_thickness_11.npy: 99.73% of the array cells are zero.
# 00055_thickness_14.npy: 99.65% of the array cells are zero.
# 00055_thickness_28.npy: 99.58% of the array cells are zero.
# 00055_thickness_24.npy: 99.57% of the array cells are zero.
# Average sparseness for thickness in model 00055: 99.67%
# Processing velocity for model_id: 00055
# 00055_velocity_23.npy: 99.03% of the array cells are zero.
# 00055_velocity_10.npy: 99.62% of the array cells are zero.
# 00055_velocity_34.npy: 99.15% of the array cells are zero.
# 00055_velocity_19.npy: 99.03% of the array cells are zero.
# 00055_velocity_3.npy: 99.85% of the array cells are zero.
# 00055_velocity_18.npy: 99.06% of the array cells are zero.
# 00055_velocity_35.npy: 99.18% of the array cells are zero.
# 00055_velocity_28.npy: 99.06% of the array cells are zero.
# 00055_velocity_24.npy: 99.05% of the array cells are zero.
# 00055_velocity_5.npy: 99.83% of the array cells are zero.
# 00055_velocity_40.npy: 99.26% of the array cells are zero.
# 00055_velocity_17.npy: 99.12% of the array cells are zero.
# 00055_velocity_29.npy: 99.06% of the array cells are zero.
# 00055_velocity_21.npy: 98.97% of the array cells are zero.
# 00055_velocity_27.npy: 99.02% of the array cells are zero.
# 00055_velocity_30.npy: 99.12% of the array cells are zero.
# 00055_velocity_42.npy: 99.33% of the array cells are zero.
# 00055_velocity_22.npy: 99.00% of the array cells are zero.
# 00055_velocity_7.npy: 99.77% of the array cells are zero.
# 00055_velocity_36.npy: 99.16% of the array cells are zero.
# 00055_velocity_4.npy: 99.86% of the array cells are zero.
# 00055_velocity_12.npy: 99.48% of the array cells are zero.
# 00055_velocity_8.npy: 99.72% of the array cells are zero.
# 00055_velocity_25.npy: 99.06% of the array cells are zero.
# 00055_velocity_9.npy: 99.67% of the array cells are zero.
# 00055_velocity_20.npy: 98.97% of the array cells are zero.
# 00055_velocity_39.npy: 99.26% of the array cells are zero.
# 00055_velocity_13.npy: 99.40% of the array cells are zero.
# 00055_velocity_2.npy: 100.00% of the array cells are zero.
# 00055_velocity_11.npy: 99.55% of the array cells are zero.
# 00055_velocity_32.npy: 99.18% of the array cells are zero.
# 00055_velocity_26.npy: 99.04% of the array cells are zero.
# 00055_velocity_38.npy: 99.23% of the array cells are zero.
# 00055_velocity_16.npy: 99.13% of the array cells are zero.
# 00055_velocity_43.npy: 99.34% of the array cells are zero.
# 00055_velocity_14.npy: 99.30% of the array cells are zero.
# 00055_velocity_33.npy: 99.14% of the array cells are zero.
# 00055_velocity_44.npy: 99.37% of the array cells are zero.
# 00055_velocity_15.npy: 99.23% of the array cells are zero.
# 00055_velocity_6.npy: 99.81% of the array cells are zero.
# 00055_velocity_41.npy: 99.31% of the array cells are zero.
# 00055_velocity_37.npy: 99.17% of the array cells are zero.
# 00055_velocity_31.npy: 99.17% of the array cells are zero.
# Average sparseness for velocity in model 00055: 99.30%
# Processing thickness for model_id: 00356
# 00356_thickness_16.npy: 99.87% of the array cells are zero.
# 00356_thickness_14.npy: 99.86% of the array cells are zero.
# 00356_thickness_34.npy: 99.85% of the array cells are zero.
# 00356_thickness_7.npy: 99.95% of the array cells are zero.
# 00356_thickness_26.npy: 99.86% of the array cells are zero.
# 00356_thickness_9.npy: 99.92% of the array cells are zero.
# 00356_thickness_23.npy: 99.86% of the array cells are zero.
# 00356_thickness_25.npy: 99.86% of the array cells are zero.
# 00356_thickness_32.npy: 99.86% of the array cells are zero.
# 00356_thickness_30.npy: 99.87% of the array cells are zero.
# 00356_thickness_21.npy: 99.87% of the array cells are zero.
# 00356_thickness_10.npy: 99.90% of the array cells are zero.
# 00356_thickness_33.npy: 99.86% of the array cells are zero.
# 00356_thickness_6.npy: 99.96% of the array cells are zero.
# 00356_thickness_29.npy: 99.87% of the array cells are zero.
# 00356_thickness_27.npy: 99.86% of the array cells are zero.
# 00356_thickness_13.npy: 99.86% of the array cells are zero.
# 00356_thickness_20.npy: 99.87% of the array cells are zero.
# 00356_thickness_3.npy: 99.96% of the array cells are zero.
# 00356_thickness_15.npy: 99.86% of the array cells are zero.
# 00356_thickness_12.npy: 99.88% of the array cells are zero.
# 00356_thickness_17.npy: 99.87% of the array cells are zero.
# 00356_thickness_8.npy: 99.94% of the array cells are zero.
# 00356_thickness_4.npy: 99.96% of the array cells are zero.
# 00356_thickness_19.npy: 99.87% of the array cells are zero.
# 00356_thickness_22.npy: 99.87% of the array cells are zero.
# 00356_thickness_31.npy: 99.86% of the array cells are zero.
# 00356_thickness_5.npy: 99.96% of the array cells are zero.
# 00356_thickness_28.npy: 99.84% of the array cells are zero.
# 00356_thickness_11.npy: 99.88% of the array cells are zero.
# 00356_thickness_24.npy: 99.86% of the array cells are zero.
# 00356_thickness_18.npy: 99.86% of the array cells are zero.
# 00356_thickness_2.npy: 99.98% of the array cells are zero.
# 00356_thickness_35.npy: 99.86% of the array cells are zero.
# Average sparseness for thickness in model 00356: 99.89%
# Processing velocity for model_id: 00356
# 00356_velocity_35.npy: 99.73% of the array cells are zero.
# 00356_velocity_7.npy: 99.91% of the array cells are zero.
# 00356_velocity_16.npy: 99.75% of the array cells are zero.
# 00356_velocity_27.npy: 99.67% of the array cells are zero.
# 00356_velocity_29.npy: 99.68% of the array cells are zero.
# 00356_velocity_20.npy: 99.72% of the array cells are zero.
# 00356_velocity_17.npy: 99.75% of the array cells are zero.
# 00356_velocity_12.npy: 99.80% of the array cells are zero.
# 00356_velocity_34.npy: 99.72% of the array cells are zero.
# 00356_velocity_8.npy: 99.89% of the array cells are zero.
# 00356_velocity_10.npy: 99.84% of the array cells are zero.
# 00356_velocity_30.npy: 99.69% of the array cells are zero.
# 00356_velocity_5.npy: 99.91% of the array cells are zero.
# 00356_velocity_15.npy: 99.77% of the array cells are zero.
# 00356_velocity_3.npy: 99.91% of the array cells are zero.
# 00356_velocity_31.npy: 99.68% of the array cells are zero.
# 00356_velocity_11.npy: 99.81% of the array cells are zero.
# 00356_velocity_21.npy: 99.72% of the array cells are zero.
# 00356_velocity_14.npy: 99.77% of the array cells are zero.
# 00356_velocity_4.npy: 99.91% of the array cells are zero.
# 00356_velocity_6.npy: 99.91% of the array cells are zero.
# 00356_velocity_23.npy: 99.72% of the array cells are zero.
# 00356_velocity_9.npy: 99.86% of the array cells are zero.
# 00356_velocity_2.npy: 100.00% of the array cells are zero.
# 00356_velocity_32.npy: 99.69% of the array cells are zero.
# 00356_velocity_33.npy: 99.70% of the array cells are zero.
# 00356_velocity_28.npy: 99.67% of the array cells are zero.
# 00356_velocity_22.npy: 99.72% of the array cells are zero.
# 00356_velocity_25.npy: 99.70% of the array cells are zero.
# 00356_velocity_19.npy: 99.73% of the array cells are zero.
# 00356_velocity_13.npy: 99.78% of the array cells are zero.
# 00356_velocity_18.npy: 99.74% of the array cells are zero.
# 00356_velocity_26.npy: 99.69% of the array cells are zero.
# 00356_velocity_24.npy: 99.71% of the array cells are zero.
# Average sparseness for velocity in model 00356: 99.77%
# Processing thickness for model_id: 00258
# 00258_thickness_22.npy: 99.87% of the array cells are zero.
# 00258_thickness_19.npy: 99.89% of the array cells are zero.
# 00258_thickness_23.npy: 99.86% of the array cells are zero.
# 00258_thickness_29.npy: 99.84% of the array cells are zero.
# 00258_thickness_16.npy: 99.90% of the array cells are zero.
# 00258_thickness_14.npy: 99.91% of the array cells are zero.
# 00258_thickness_9.npy: 99.92% of the array cells are zero.
# 00258_thickness_2.npy: 99.98% of the array cells are zero.
# 00258_thickness_20.npy: 99.88% of the array cells are zero.
# 00258_thickness_18.npy: 99.89% of the array cells are zero.
# 00258_thickness_17.npy: 99.89% of the array cells are zero.
# 00258_thickness_12.npy: 99.91% of the array cells are zero.
# 00258_thickness_7.npy: 99.95% of the array cells are zero.
# 00258_thickness_3.npy: 99.97% of the array cells are zero.
# 00258_thickness_24.npy: 99.85% of the array cells are zero.
# 00258_thickness_6.npy: 99.96% of the array cells are zero.
# 00258_thickness_26.npy: 99.84% of the array cells are zero.
# 00258_thickness_32.npy: 99.85% of the array cells are zero.
# 00258_thickness_21.npy: 99.87% of the array cells are zero.
# 00258_thickness_4.npy: 99.96% of the array cells are zero.
# 00258_thickness_25.npy: 99.84% of the array cells are zero.
# 00258_thickness_10.npy: 99.92% of the array cells are zero.
# 00258_thickness_15.npy: 99.90% of the array cells are zero.
# 00258_thickness_8.npy: 99.94% of the array cells are zero.
# 00258_thickness_13.npy: 99.91% of the array cells are zero.
# 00258_thickness_35.npy: 99.85% of the array cells are zero.
# 00258_thickness_5.npy: 99.96% of the array cells are zero.
# 00258_thickness_11.npy: 99.91% of the array cells are zero.
# 00258_thickness_31.npy: 99.84% of the array cells are zero.
# 00258_thickness_34.npy: 99.85% of the array cells are zero.
# 00258_thickness_33.npy: 99.85% of the array cells are zero.
# 00258_thickness_27.npy: 99.85% of the array cells are zero.
# 00258_thickness_30.npy: 99.84% of the array cells are zero.
# 00258_thickness_28.npy: 99.85% of the array cells are zero.
# Average sparseness for thickness in model 00258: 99.89%
# Processing velocity for model_id: 00258
# 00258_velocity_2.npy: 100.00% of the array cells are zero.
# 00258_velocity_31.npy: 99.68% of the array cells are zero.
# 00258_velocity_20.npy: 99.75% of the array cells are zero.
# 00258_velocity_15.npy: 99.79% of the array cells are zero.
# 00258_velocity_32.npy: 99.68% of the array cells are zero.
# 00258_velocity_24.npy: 99.71% of the array cells are zero.
# 00258_velocity_33.npy: 99.68% of the array cells are zero.
# 00258_velocity_7.npy: 99.91% of the array cells are zero.
# 00258_velocity_3.npy: 99.91% of the array cells are zero.
# 00258_velocity_28.npy: 99.69% of the array cells are zero.
# 00258_velocity_35.npy: 99.68% of the array cells are zero.
# 00258_velocity_9.npy: 99.86% of the array cells are zero.
# 00258_velocity_22.npy: 99.73% of the array cells are zero.
# 00258_velocity_17.npy: 99.78% of the array cells are zero.
# 00258_velocity_34.npy: 99.68% of the array cells are zero.
# 00258_velocity_13.npy: 99.82% of the array cells are zero.
# 00258_velocity_21.npy: 99.75% of the array cells are zero.
# 00258_velocity_10.npy: 99.84% of the array cells are zero.
# 00258_velocity_12.npy: 99.83% of the array cells are zero.
# 00258_velocity_23.npy: 99.72% of the array cells are zero.
# 00258_velocity_27.npy: 99.69% of the array cells are zero.
# 00258_velocity_18.npy: 99.77% of the array cells are zero.
# 00258_velocity_25.npy: 99.70% of the array cells are zero.
# 00258_velocity_30.npy: 99.68% of the array cells are zero.
# 00258_velocity_5.npy: 99.92% of the array cells are zero.
# 00258_velocity_14.npy: 99.80% of the array cells are zero.
# 00258_velocity_19.npy: 99.77% of the array cells are zero.
# 00258_velocity_11.npy: 99.84% of the array cells are zero.
# 00258_velocity_4.npy: 99.91% of the array cells are zero.
# 00258_velocity_26.npy: 99.69% of the array cells are zero.
# 00258_velocity_16.npy: 99.80% of the array cells are zero.
# 00258_velocity_6.npy: 99.92% of the array cells are zero.
# 00258_velocity_8.npy: 99.88% of the array cells are zero.
# 00258_velocity_29.npy: 99.67% of the array cells are zero.
# Average sparseness for velocity in model 00258: 99.78%
# Processing thickness for model_id: 00281
# 00281_thickness_10.npy: 99.94% of the array cells are zero.
# 00281_thickness_29.npy: 99.89% of the array cells are zero.
# 00281_thickness_12.npy: 99.93% of the array cells are zero.
# 00281_thickness_31.npy: 99.90% of the array cells are zero.
# 00281_thickness_44.npy: 99.91% of the array cells are zero.
# 00281_thickness_6.npy: 99.98% of the array cells are zero.
# 00281_thickness_9.npy: 99.95% of the array cells are zero.
# 00281_thickness_16.npy: 99.90% of the array cells are zero.
# 00281_thickness_32.npy: 99.90% of the array cells are zero.
# 00281_thickness_35.npy: 99.91% of the array cells are zero.
# 00281_thickness_36.npy: 99.90% of the array cells are zero.
# 00281_thickness_37.npy: 99.90% of the array cells are zero.
# 00281_thickness_38.npy: 99.91% of the array cells are zero.
# 00281_thickness_11.npy: 99.93% of the array cells are zero.
# 00281_thickness_25.npy: 99.86% of the array cells are zero.
# 00281_thickness_45.npy: 99.90% of the array cells are zero.
# 00281_thickness_20.npy: 99.87% of the array cells are zero.
# 00281_thickness_21.npy: 99.89% of the array cells are zero.
# 00281_thickness_8.npy: 99.97% of the array cells are zero.
# 00281_thickness_18.npy: 99.89% of the array cells are zero.
# 00281_thickness_40.npy: 99.91% of the array cells are zero.
# 00281_thickness_13.npy: 99.92% of the array cells are zero.
# 00281_thickness_19.npy: 99.88% of the array cells are zero.
# 00281_thickness_22.npy: 99.88% of the array cells are zero.
# 00281_thickness_41.npy: 99.91% of the array cells are zero.
# 00281_thickness_4.npy: 99.98% of the array cells are zero.
# 00281_thickness_15.npy: 99.91% of the array cells are zero.
# 00281_thickness_17.npy: 99.90% of the array cells are zero.
# 00281_thickness_5.npy: 99.98% of the array cells are zero.
# 00281_thickness_7.npy: 99.98% of the array cells are zero.
# 00281_thickness_23.npy: 99.88% of the array cells are zero.
# 00281_thickness_28.npy: 99.88% of the array cells are zero.
# 00281_thickness_2.npy: 99.99% of the array cells are zero.
# 00281_thickness_42.npy: 99.91% of the array cells are zero.
# 00281_thickness_27.npy: 99.87% of the array cells are zero.
# 00281_thickness_30.npy: 99.89% of the array cells are zero.
# 00281_thickness_14.npy: 99.91% of the array cells are zero.
# 00281_thickness_24.npy: 99.87% of the array cells are zero.
# 00281_thickness_3.npy: 99.99% of the array cells are zero.
# 00281_thickness_43.npy: 99.91% of the array cells are zero.
# 00281_thickness_39.npy: 99.90% of the array cells are zero.
# 00281_thickness_33.npy: 99.89% of the array cells are zero.
# 00281_thickness_26.npy: 99.87% of the array cells are zero.
# 00281_thickness_34.npy: 99.90% of the array cells are zero.
# Average sparseness for thickness in model 00281: 99.91%
# Processing velocity for model_id: 00281
# 00281_velocity_37.npy: 99.74% of the array cells are zero.
# 00281_velocity_7.npy: 99.95% of the array cells are zero.
# 00281_velocity_6.npy: 99.95% of the array cells are zero.
# 00281_velocity_16.npy: 99.80% of the array cells are zero.
# 00281_velocity_34.npy: 99.74% of the array cells are zero.
# 00281_velocity_4.npy: 99.95% of the array cells are zero.
# 00281_velocity_2.npy: 100.00% of the array cells are zero.
# 00281_velocity_5.npy: 99.95% of the array cells are zero.
# 00281_velocity_20.npy: 99.73% of the array cells are zero.
# 00281_velocity_11.npy: 99.87% of the array cells are zero.
# 00281_velocity_17.npy: 99.78% of the array cells are zero.
# 00281_velocity_23.npy: 99.68% of the array cells are zero.
# 00281_velocity_8.npy: 99.93% of the array cells are zero.
# 00281_velocity_31.npy: 99.73% of the array cells are zero.
# 00281_velocity_22.npy: 99.69% of the array cells are zero.
# 00281_velocity_24.npy: 99.67% of the array cells are zero.
# 00281_velocity_18.npy: 99.77% of the array cells are zero.
# 00281_velocity_28.npy: 99.70% of the array cells are zero.
# 00281_velocity_44.npy: 99.75% of the array cells are zero.
# 00281_velocity_33.npy: 99.74% of the array cells are zero.
# 00281_velocity_41.npy: 99.76% of the array cells are zero.
# 00281_velocity_15.npy: 99.82% of the array cells are zero.
# 00281_velocity_13.npy: 99.85% of the array cells are zero.
# 00281_velocity_10.npy: 99.90% of the array cells are zero.
# 00281_velocity_25.npy: 99.67% of the array cells are zero.
# 00281_velocity_38.npy: 99.75% of the array cells are zero.
# 00281_velocity_21.npy: 99.71% of the array cells are zero.
# 00281_velocity_36.npy: 99.73% of the array cells are zero.
# 00281_velocity_27.npy: 99.69% of the array cells are zero.
# 00281_velocity_40.npy: 99.75% of the array cells are zero.
# 00281_velocity_39.npy: 99.75% of the array cells are zero.
# 00281_velocity_29.npy: 99.71% of the array cells are zero.
# 00281_velocity_12.npy: 99.86% of the array cells are zero.
# 00281_velocity_32.npy: 99.73% of the array cells are zero.
# 00281_velocity_9.npy: 99.91% of the array cells are zero.
# 00281_velocity_19.npy: 99.75% of the array cells are zero.
# 00281_velocity_43.npy: 99.76% of the array cells are zero.
# 00281_velocity_45.npy: 99.75% of the array cells are zero.
# 00281_velocity_26.npy: 99.66% of the array cells are zero.
# 00281_velocity_30.npy: 99.71% of the array cells are zero.
# 00281_velocity_35.npy: 99.73% of the array cells are zero.
# 00281_velocity_14.npy: 99.83% of the array cells are zero.
# 00281_velocity_42.npy: 99.77% of the array cells are zero.
# 00281_velocity_3.npy: 99.95% of the array cells are zero.
# Average sparseness for velocity in model 00281: 99.79%
# Processing thickness for model_id: 00104
# 00104_thickness_16.npy: 99.88% of the array cells are zero.
# 00104_thickness_23.npy: 99.89% of the array cells are zero.
# 00104_thickness_30.npy: 99.86% of the array cells are zero.
# 00104_thickness_17.npy: 99.88% of the array cells are zero.
# 00104_thickness_9.npy: 99.92% of the array cells are zero.
# 00104_thickness_5.npy: 99.94% of the array cells are zero.
# 00104_thickness_19.npy: 99.88% of the array cells are zero.
# 00104_thickness_41.npy: 99.77% of the array cells are zero.
# 00104_thickness_35.npy: 99.81% of the array cells are zero.
# 00104_thickness_2.npy: 99.94% of the array cells are zero.
# 00104_thickness_18.npy: 99.87% of the array cells are zero.
# 00104_thickness_43.npy: 99.77% of the array cells are zero.
# 00104_thickness_26.npy: 99.89% of the array cells are zero.
# 00104_thickness_7.npy: 99.94% of the array cells are zero.
# 00104_thickness_34.npy: 99.82% of the array cells are zero.
# 00104_thickness_28.npy: 99.88% of the array cells are zero.
# 00104_thickness_13.npy: 99.89% of the array cells are zero.
# 00104_thickness_50.npy: 99.79% of the array cells are zero.
# 00104_thickness_32.npy: 99.83% of the array cells are zero.
# 00104_thickness_4.npy: 99.94% of the array cells are zero.
# 00104_thickness_10.npy: 99.91% of the array cells are zero.
# 00104_thickness_11.npy: 99.89% of the array cells are zero.
# 00104_thickness_22.npy: 99.88% of the array cells are zero.
# 00104_thickness_47.npy: 99.79% of the array cells are zero.
# 00104_thickness_24.npy: 99.89% of the array cells are zero.
# 00104_thickness_6.npy: 99.94% of the array cells are zero.
# 00104_thickness_40.npy: 99.77% of the array cells are zero.
# 00104_thickness_44.npy: 99.77% of the array cells are zero.
# 00104_thickness_15.npy: 99.89% of the array cells are zero.
# 00104_thickness_12.npy: 99.89% of the array cells are zero.
# 00104_thickness_36.npy: 99.81% of the array cells are zero.
# 00104_thickness_20.npy: 99.87% of the array cells are zero.
# 00104_thickness_21.npy: 99.88% of the array cells are zero.
# 00104_thickness_42.npy: 99.77% of the array cells are zero.
# 00104_thickness_14.npy: 99.89% of the array cells are zero.
# 00104_thickness_48.npy: 99.79% of the array cells are zero.
# 00104_thickness_37.npy: 99.80% of the array cells are zero.
# 00104_thickness_29.npy: 99.87% of the array cells are zero.
# 00104_thickness_8.npy: 99.93% of the array cells are zero.
# 00104_thickness_33.npy: 99.83% of the array cells are zero.
# 00104_thickness_45.npy: 99.78% of the array cells are zero.
# 00104_thickness_46.npy: 99.78% of the array cells are zero.
# 00104_thickness_31.npy: 99.85% of the array cells are zero.
# 00104_thickness_49.npy: 99.79% of the array cells are zero.
# 00104_thickness_38.npy: 99.79% of the array cells are zero.
# 00104_thickness_3.npy: 99.94% of the array cells are zero.
# 00104_thickness_39.npy: 99.78% of the array cells are zero.
# 00104_thickness_25.npy: 99.89% of the array cells are zero.
# 00104_thickness_27.npy: 99.89% of the array cells are zero.
# Average sparseness for thickness in model 00104: 99.86%
# Processing velocity for model_id: 00104
# 00104_velocity_26.npy: 99.80% of the array cells are zero.
# 00104_velocity_13.npy: 99.82% of the array cells are zero.
# 00104_velocity_36.npy: 99.65% of the array cells are zero.
# 00104_velocity_25.npy: 99.82% of the array cells are zero.
# 00104_velocity_2.npy: 100.00% of the array cells are zero.
# 00104_velocity_34.npy: 99.69% of the array cells are zero.
# 00104_velocity_30.npy: 99.75% of the array cells are zero.
# 00104_velocity_5.npy: 99.89% of the array cells are zero.
# 00104_velocity_24.npy: 99.81% of the array cells are zero.
# 00104_velocity_21.npy: 99.78% of the array cells are zero.
# 00104_velocity_45.npy: 99.63% of the array cells are zero.
# 00104_velocity_6.npy: 99.89% of the array cells are zero.
# 00104_velocity_29.npy: 99.77% of the array cells are zero.
# 00104_velocity_49.npy: 99.64% of the array cells are zero.
# 00104_velocity_33.npy: 99.70% of the array cells are zero.
# 00104_velocity_50.npy: 99.64% of the array cells are zero.
# 00104_velocity_23.npy: 99.80% of the array cells are zero.
# 00104_velocity_7.npy: 99.89% of the array cells are zero.
# 00104_velocity_4.npy: 99.89% of the array cells are zero.
# 00104_velocity_14.npy: 99.82% of the array cells are zero.
# 00104_velocity_20.npy: 99.78% of the array cells are zero.
# 00104_velocity_38.npy: 99.63% of the array cells are zero.
# 00104_velocity_28.npy: 99.80% of the array cells are zero.
# 00104_velocity_40.npy: 99.62% of the array cells are zero.
# 00104_velocity_18.npy: 99.78% of the array cells are zero.
# 00104_velocity_41.npy: 99.60% of the array cells are zero.
# 00104_velocity_37.npy: 99.63% of the array cells are zero.
# 00104_velocity_35.npy: 99.67% of the array cells are zero.
# 00104_velocity_10.npy: 99.84% of the array cells are zero.
# 00104_velocity_11.npy: 99.83% of the array cells are zero.
# 00104_velocity_12.npy: 99.82% of the array cells are zero.
# 00104_velocity_31.npy: 99.74% of the array cells are zero.
# 00104_velocity_44.npy: 99.61% of the array cells are zero.
# 00104_velocity_3.npy: 99.89% of the array cells are zero.
# 00104_velocity_32.npy: 99.72% of the array cells are zero.
# 00104_velocity_46.npy: 99.63% of the array cells are zero.
# 00104_velocity_8.npy: 99.87% of the array cells are zero.
# 00104_velocity_15.npy: 99.81% of the array cells are zero.
# 00104_velocity_19.npy: 99.78% of the array cells are zero.
# 00104_velocity_47.npy: 99.64% of the array cells are zero.
# 00104_velocity_9.npy: 99.85% of the array cells are zero.
# 00104_velocity_16.npy: 99.82% of the array cells are zero.
# 00104_velocity_22.npy: 99.79% of the array cells are zero.
# 00104_velocity_43.npy: 99.60% of the array cells are zero.
# 00104_velocity_48.npy: 99.64% of the array cells are zero.
# 00104_velocity_39.npy: 99.61% of the array cells are zero.
# 00104_velocity_42.npy: 99.59% of the array cells are zero.
# 00104_velocity_17.npy: 99.80% of the array cells are zero.
# 00104_velocity_27.npy: 99.80% of the array cells are zero.
# Average sparseness for velocity in model 00104: 99.75%
# Processing thickness for model_id: 00304
# 00304_thickness_2.npy: 99.93% of the array cells are zero.
# 00304_thickness_45.npy: 99.62% of the array cells are zero.
# 00304_thickness_48.npy: 99.60% of the array cells are zero.
# 00304_thickness_11.npy: 99.83% of the array cells are zero.
# 00304_thickness_25.npy: 99.81% of the array cells are zero.
# 00304_thickness_38.npy: 99.69% of the array cells are zero.
# 00304_thickness_20.npy: 99.84% of the array cells are zero.
# 00304_thickness_46.npy: 99.61% of the array cells are zero.
# 00304_thickness_43.npy: 99.63% of the array cells are zero.
# 00304_thickness_12.npy: 99.81% of the array cells are zero.
# 00304_thickness_24.npy: 99.82% of the array cells are zero.
# 00304_thickness_29.npy: 99.79% of the array cells are zero.
# 00304_thickness_5.npy: 99.92% of the array cells are zero.
# 00304_thickness_8.npy: 99.85% of the array cells are zero.
# 00304_thickness_42.npy: 99.65% of the array cells are zero.
# 00304_thickness_4.npy: 99.92% of the array cells are zero.
# 00304_thickness_3.npy: 99.93% of the array cells are zero.
# 00304_thickness_19.npy: 99.86% of the array cells are zero.
# 00304_thickness_32.npy: 99.76% of the array cells are zero.
# 00304_thickness_34.npy: 99.73% of the array cells are zero.
# 00304_thickness_22.npy: 99.83% of the array cells are zero.
# 00304_thickness_17.npy: 99.86% of the array cells are zero.
# 00304_thickness_7.npy: 99.86% of the array cells are zero.
# 00304_thickness_14.npy: 99.84% of the array cells are zero.
# 00304_thickness_36.npy: 99.72% of the array cells are zero.
# 00304_thickness_28.npy: 99.79% of the array cells are zero.
# 00304_thickness_47.npy: 99.61% of the array cells are zero.
# 00304_thickness_26.npy: 99.80% of the array cells are zero.
# 00304_thickness_41.npy: 99.65% of the array cells are zero.
# 00304_thickness_35.npy: 99.73% of the array cells are zero.
# 00304_thickness_16.npy: 99.86% of the array cells are zero.
# 00304_thickness_13.npy: 99.82% of the array cells are zero.
# 00304_thickness_6.npy: 99.92% of the array cells are zero.
# 00304_thickness_33.npy: 99.75% of the array cells are zero.
# 00304_thickness_10.npy: 99.83% of the array cells are zero.
# 00304_thickness_44.npy: 99.62% of the array cells are zero.
# 00304_thickness_39.npy: 99.68% of the array cells are zero.
# 00304_thickness_31.npy: 99.77% of the array cells are zero.
# 00304_thickness_37.npy: 99.71% of the array cells are zero.
# 00304_thickness_50.npy: 99.58% of the array cells are zero.
# 00304_thickness_15.npy: 99.85% of the array cells are zero.
# 00304_thickness_18.npy: 99.86% of the array cells are zero.
# 00304_thickness_9.npy: 99.84% of the array cells are zero.
# 00304_thickness_23.npy: 99.82% of the array cells are zero.
# 00304_thickness_49.npy: 99.59% of the array cells are zero.
# 00304_thickness_30.npy: 99.78% of the array cells are zero.
# 00304_thickness_40.npy: 99.67% of the array cells are zero.
# 00304_thickness_27.npy: 99.79% of the array cells are zero.
# 00304_thickness_21.npy: 99.83% of the array cells are zero.
# Average sparseness for thickness in model 00304: 99.77%
# Processing velocity for model_id: 00304
# 00304_velocity_11.npy: 99.67% of the array cells are zero.
# 00304_velocity_21.npy: 99.63% of the array cells are zero.
# 00304_velocity_20.npy: 99.68% of the array cells are zero.
# 00304_velocity_44.npy: 99.24% of the array cells are zero.
# 00304_velocity_31.npy: 99.53% of the array cells are zero.
# 00304_velocity_37.npy: 99.41% of the array cells are zero.
# 00304_velocity_9.npy: 99.71% of the array cells are zero.
# 00304_velocity_15.npy: 99.71% of the array cells are zero.
# 00304_velocity_38.npy: 99.40% of the array cells are zero.
# 00304_velocity_35.npy: 99.44% of the array cells are zero.
# ...
# 00384_velocity_40.npy: 99.72% of the array cells are zero.
# 00384_velocity_88.npy: 99.47% of the array cells are zero.
# 00384_velocity_60.npy: 99.61% of the array cells are zero.
# 00384_velocity_47.npy: 99.66% of the array cells are zero.
# 00384_velocity_68.npy: 99.58% of the array cells are zero.
# 00384_velocity_48.npy: 99.66% of the array cells are zero.
# 00384_velocity_4.npy: 99.88% of the array cells are zero.
# 00384_velocity_73.npy: 99.57% of the array cells are zero.
# 00384_velocity_21.npy: 99.72% of the array cells are zero.
# 00384_velocity_65.npy: 99.60% of the array cells are zero.
# 00384_velocity_46.npy: 99.67% of the array cells are zero.
# 00384_velocity_25.npy: 99.77% of the array cells are zero.
# 00384_velocity_34.npy: 99.76% of the array cells are zero.
# 00384_velocity_41.npy: 99.71% of the array cells are zero.
# 00384_velocity_2.npy: 100.00% of the array cells are zero.
# 00384_velocity_89.npy: 99.43% of the array cells are zero.
# 00384_velocity_19.npy: 99.71% of the array cells are zero.
# 00384_velocity_15.npy: 99.72% of the array cells are zero.
# 00384_velocity_70.npy: 99.57% of the array cells are zero.
# 00384_velocity_53.npy: 99.64% of the array cells are zero.
# 00384_velocity_100.npy: 99.43% of the array cells are zero.
# 00384_velocity_30.npy: 99.79% of the array cells are zero.
# 00384_velocity_104.npy: 99.42% of the array cells are zero.
# 00384_velocity_98.npy: 99.42% of the array cells are zero.
# 00384_velocity_81.npy: 99.53% of the array cells are zero.
# 00384_velocity_83.npy: 99.47% of the array cells are zero.
# 00384_velocity_37.npy: 99.74% of the array cells are zero.
# 00384_velocity_99.npy: 99.43% of the array cells are zero.
# 00384_velocity_38.npy: 99.73% of the array cells are zero.
# 00384_velocity_95.npy: 99.45% of the array cells are zero.
# 00384_velocity_69.npy: 99.57% of the array cells are zero.
# 00384_velocity_39.npy: 99.72% of the array cells are zero.
# 00384_velocity_91.npy: 99.44% of the array cells are zero.
# 00384_velocity_50.npy: 99.65% of the array cells are zero.
# 00384_velocity_105.npy: 99.43% of the array cells are zero.
# 00384_velocity_62.npy: 99.60% of the array cells are zero.
# 00384_velocity_29.npy: 99.79% of the array cells are zero.
# 00384_velocity_57.npy: 99.61% of the array cells are zero.
# 00384_velocity_51.npy: 99.65% of the array cells are zero.
# 00384_velocity_16.npy: 99.72% of the array cells are zero.
# 00384_velocity_5.npy: 99.88% of the array cells are zero.
# 00384_velocity_28.npy: 99.79% of the array cells are zero.
# 00384_velocity_75.npy: 99.54% of the array cells are zero.
# 00384_velocity_64.npy: 99.60% of the array cells are zero.
# 00384_velocity_92.npy: 99.44% of the array cells are zero.
# 00384_velocity_49.npy: 99.65% of the array cells are zero.
# 00384_velocity_17.npy: 99.73% of the array cells are zero.
# 00384_velocity_55.npy: 99.61% of the array cells are zero.
# 00384_velocity_59.npy: 99.61% of the array cells are zero.
# 00384_velocity_63.npy: 99.61% of the array cells are zero.
# 00384_velocity_14.npy: 99.73% of the array cells are zero.
# 00384_velocity_77.npy: 99.53% of the array cells are zero.
# 00384_velocity_74.npy: 99.56% of the array cells are zero.
# 00384_velocity_61.npy: 99.60% of the array cells are zero.
# 00384_velocity_7.npy: 99.88% of the array cells are zero.
# 00384_velocity_93.npy: 99.44% of the array cells are zero.
# 00384_velocity_32.npy: 99.77% of the array cells are zero.
# 00384_velocity_90.npy: 99.44% of the array cells are zero.
# 00384_velocity_58.npy: 99.61% of the array cells are zero.
# 00384_velocity_12.npy: 99.75% of the array cells are zero.
# 00384_velocity_45.npy: 99.67% of the array cells are zero.
# 00384_velocity_36.npy: 99.75% of the array cells are zero.
# 00384_velocity_78.npy: 99.52% of the array cells are zero.
# 00384_velocity_54.npy: 99.63% of the array cells are zero.
# 00384_velocity_10.npy: 99.78% of the array cells are zero.
# 00384_velocity_94.npy: 99.44% of the array cells are zero.
# 00384_velocity_22.npy: 99.73% of the array cells are zero.
# 00384_velocity_44.npy: 99.68% of the array cells are zero.
# 00384_velocity_42.npy: 99.70% of the array cells are zero.
# 00384_velocity_56.npy: 99.61% of the array cells are zero.
# 00384_velocity_79.npy: 99.52% of the array cells are zero.
# 00384_velocity_23.npy: 99.75% of the array cells are zero.
# 00384_velocity_87.npy: 99.46% of the array cells are zero.
# 00384_velocity_67.npy: 99.60% of the array cells are zero.
# 00384_velocity_26.npy: 99.79% of the array cells are zero.
# 00384_velocity_71.npy: 99.55% of the array cells are zero.
# 00384_velocity_11.npy: 99.77% of the array cells are zero.
# 00384_velocity_20.npy: 99.71% of the array cells are zero.
# 00384_velocity_43.npy: 99.69% of the array cells are zero.
# 00384_velocity_31.npy: 99.78% of the array cells are zero.
# 00384_velocity_13.npy: 99.73% of the array cells are zero.
# 00384_velocity_9.npy: 99.81% of the array cells are zero.
# 00384_velocity_72.npy: 99.56% of the array cells are zero.
# 00384_velocity_3.npy: 99.88% of the array cells are zero.
# 00384_velocity_27.npy: 99.78% of the array cells are zero.
# 00384_velocity_8.npy: 99.86% of the array cells are zero.
# 00384_velocity_76.npy: 99.50% of the array cells are zero.
# 00384_velocity_82.npy: 99.50% of the array cells are zero.
# 00384_velocity_101.npy: 99.44% of the array cells are zero.
# 00384_velocity_52.npy: 99.64% of the array cells are zero.
# 00384_velocity_33.npy: 99.77% of the array cells are zero.
# 00384_velocity_84.npy: 99.45% of the array cells are zero.
# 00384_velocity_86.npy: 99.45% of the array cells are zero.
# 00384_velocity_35.npy: 99.75% of the array cells are zero.
# 00384_velocity_96.npy: 99.43% of the array cells are zero.
# 00384_velocity_97.npy: 99.43% of the array cells are zero.
# 00384_velocity_102.npy: 99.45% of the array cells are zero.
# 00384_velocity_66.npy: 99.60% of the array cells are zero.
# 00384_velocity_80.npy: 99.53% of the array cells are zero.
# 00384_velocity_103.npy: 99.42% of the array cells are zero.
# 00384_velocity_24.npy: 99.76% of the array cells are zero.
# 00384_velocity_6.npy: 99.89% of the array cells are zero.
# Average sparseness for velocity in model 00384: 99.63%
# Processing thickness for model_id: 00200
# 00200_thickness_3.npy: 99.97% of the array cells are zero.
# 00200_thickness_55.npy: 99.77% of the array cells are zero.
# 00200_thickness_28.npy: 99.86% of the array cells are zero.
# 00200_thickness_36.npy: 99.85% of the array cells are zero.
# 00200_thickness_33.npy: 99.86% of the array cells are zero.
# 00200_thickness_38.npy: 99.84% of the array cells are zero.
# 00200_thickness_47.npy: 99.78% of the array cells are zero.
# 00200_thickness_50.npy: 99.78% of the array cells are zero.
# 00200_thickness_29.npy: 99.86% of the array cells are zero.
# 00200_thickness_56.npy: 99.76% of the array cells are zero.
# 00200_thickness_13.npy: 99.93% of the array cells are zero.
# 00200_thickness_22.npy: 99.90% of the array cells are zero.
# 00200_thickness_34.npy: 99.86% of the array cells are zero.
# 00200_thickness_45.npy: 99.79% of the array cells are zero.
# 00200_thickness_40.npy: 99.83% of the array cells are zero.
# 00200_thickness_54.npy: 99.76% of the array cells are zero.
# 00200_thickness_43.npy: 99.81% of the array cells are zero.
# 00200_thickness_49.npy: 99.78% of the array cells are zero.
# 00200_thickness_60.npy: 99.75% of the array cells are zero.
# 00200_thickness_31.npy: 99.85% of the array cells are zero.
# 00200_thickness_27.npy: 99.87% of the array cells are zero.
# 00200_thickness_35.npy: 99.85% of the array cells are zero.
# 00200_thickness_32.npy: 99.85% of the array cells are zero.
# 00200_thickness_41.npy: 99.83% of the array cells are zero.
# 00200_thickness_20.npy: 99.92% of the array cells are zero.
# 00200_thickness_7.npy: 99.96% of the array cells are zero.
# 00200_thickness_51.npy: 99.78% of the array cells are zero.
# 00200_thickness_6.npy: 99.96% of the array cells are zero.
# 00200_thickness_24.npy: 99.90% of the array cells are zero.
# 00200_thickness_44.npy: 99.80% of the array cells are zero.
# 00200_thickness_48.npy: 99.78% of the array cells are zero.
# 00200_thickness_37.npy: 99.84% of the array cells are zero.
# 00200_thickness_46.npy: 99.79% of the array cells are zero.
# 00200_thickness_17.npy: 99.94% of the array cells are zero.
# 00200_thickness_10.npy: 99.93% of the array cells are zero.
# 00200_thickness_58.npy: 99.75% of the array cells are zero.
# 00200_thickness_39.npy: 99.84% of the array cells are zero.
# 00200_thickness_14.npy: 99.93% of the array cells are zero.
# 00200_thickness_5.npy: 99.96% of the array cells are zero.
# 00200_thickness_19.npy: 99.93% of the array cells are zero.
# 00200_thickness_42.npy: 99.82% of the array cells are zero.
# 00200_thickness_23.npy: 99.89% of the array cells are zero.
# 00200_thickness_8.npy: 99.95% of the array cells are zero.
# 00200_thickness_52.npy: 99.78% of the array cells are zero.
# 00200_thickness_59.npy: 99.75% of the array cells are zero.
# 00200_thickness_16.npy: 99.94% of the array cells are zero.
# 00200_thickness_11.npy: 99.93% of the array cells are zero.
# 00200_thickness_12.npy: 99.92% of the array cells are zero.
# 00200_thickness_9.npy: 99.93% of the array cells are zero.
# 00200_thickness_26.npy: 99.89% of the array cells are zero.
# 00200_thickness_53.npy: 99.77% of the array cells are zero.
# 00200_thickness_4.npy: 99.96% of the array cells are zero.
# 00200_thickness_2.npy: 99.98% of the array cells are zero.
# 00200_thickness_21.npy: 99.91% of the array cells are zero.
# 00200_thickness_18.npy: 99.93% of the array cells are zero.
# 00200_thickness_15.npy: 99.94% of the array cells are zero.
# 00200_thickness_30.npy: 99.85% of the array cells are zero.
# 00200_thickness_25.npy: 99.90% of the array cells are zero.
# 00200_thickness_57.npy: 99.76% of the array cells are zero.
# Average sparseness for thickness in model 00200: 99.86%
# Processing velocity for model_id: 00200
# 00200_velocity_19.npy: 99.86% of the array cells are zero.
# 00200_velocity_53.npy: 99.53% of the array cells are zero.
# 00200_velocity_28.npy: 99.73% of the array cells are zero.
# 00200_velocity_23.npy: 99.81% of the array cells are zero.
# 00200_velocity_20.npy: 99.85% of the array cells are zero.
# 00200_velocity_2.npy: 100.00% of the array cells are zero.
# 00200_velocity_59.npy: 99.48% of the array cells are zero.
# 00200_velocity_44.npy: 99.56% of the array cells are zero.
# 00200_velocity_24.npy: 99.82% of the array cells are zero.
# 00200_velocity_39.npy: 99.66% of the array cells are zero.
# 00200_velocity_38.npy: 99.67% of the array cells are zero.
# 00200_velocity_16.npy: 99.88% of the array cells are zero.
# 00200_velocity_25.npy: 99.82% of the array cells are zero.
# 00200_velocity_12.npy: 99.86% of the array cells are zero.
# 00200_velocity_47.npy: 99.52% of the array cells are zero.
# 00200_velocity_3.npy: 99.92% of the array cells are zero.
# 00200_velocity_8.npy: 99.89% of the array cells are zero.
# 00200_velocity_5.npy: 99.92% of the array cells are zero.
# 00200_velocity_46.npy: 99.53% of the array cells are zero.
# 00200_velocity_54.npy: 99.51% of the array cells are zero.
# 00200_velocity_30.npy: 99.68% of the array cells are zero.
# 00200_velocity_15.npy: 99.85% of the array cells are zero.
# 00200_velocity_58.npy: 99.49% of the array cells are zero.
# 00200_velocity_37.npy: 99.67% of the array cells are zero.
# 00200_velocity_43.npy: 99.60% of the array cells are zero.
# 00200_velocity_22.npy: 99.83% of the array cells are zero.
# 00200_velocity_6.npy: 99.92% of the array cells are zero.
# 00200_velocity_17.npy: 99.87% of the array cells are zero.
# 00200_velocity_4.npy: 99.92% of the array cells are zero.
# 00200_velocity_35.npy: 99.66% of the array cells are zero.
# 00200_velocity_40.npy: 99.64% of the array cells are zero.
# 00200_velocity_51.npy: 99.53% of the array cells are zero.
# 00200_velocity_48.npy: 99.53% of the array cells are zero.
# 00200_velocity_29.npy: 99.71% of the array cells are zero.
# 00200_velocity_34.npy: 99.64% of the array cells are zero.
# 00200_velocity_26.npy: 99.78% of the array cells are zero.
# 00200_velocity_11.npy: 99.86% of the array cells are zero.
# 00200_velocity_10.npy: 99.87% of the array cells are zero.
# 00200_velocity_60.npy: 99.47% of the array cells are zero.
# 00200_velocity_49.npy: 99.54% of the array cells are zero.
# 00200_velocity_9.npy: 99.88% of the array cells are zero.
# 00200_velocity_52.npy: 99.53% of the array cells are zero.
# 00200_velocity_7.npy: 99.91% of the array cells are zero.
# 00200_velocity_57.npy: 99.51% of the array cells are zero.
# 00200_velocity_36.npy: 99.67% of the array cells are zero.
# 00200_velocity_14.npy: 99.86% of the array cells are zero.
# 00200_velocity_13.npy: 99.86% of the array cells are zero.
# 00200_velocity_50.npy: 99.52% of the array cells are zero.
# 00200_velocity_41.npy: 99.62% of the array cells are zero.
# 00200_velocity_55.npy: 99.51% of the array cells are zero.
# 00200_velocity_42.npy: 99.61% of the array cells are zero.
# 00200_velocity_32.npy: 99.67% of the array cells are zero.
# 00200_velocity_18.npy: 99.87% of the array cells are zero.
# 00200_velocity_56.npy: 99.51% of the array cells are zero.
# 00200_velocity_45.npy: 99.55% of the array cells are zero.
# 00200_velocity_31.npy: 99.65% of the array cells are zero.
# 00200_velocity_33.npy: 99.66% of the array cells are zero.
# 00200_velocity_27.npy: 99.77% of the array cells are zero.
# 00200_velocity_21.npy: 99.83% of the array cells are zero.
# Average sparseness for velocity in model 00200: 99.71%
# Processing thickness for model_id: 00072
# 00072_thickness_21.npy: 99.77% of the array cells are zero.
# 00072_thickness_5.npy: 99.89% of the array cells are zero.
# 00072_thickness_11.npy: 99.76% of the array cells are zero.
# 00072_thickness_13.npy: 99.73% of the array cells are zero.
# 00072_thickness_2.npy: 99.93% of the array cells are zero.
# 00072_thickness_8.npy: 99.81% of the array cells are zero.
# 00072_thickness_15.npy: 99.71% of the array cells are zero.
# 00072_thickness_18.npy: 99.70% of the array cells are zero.
# 00072_thickness_10.npy: 99.77% of the array cells are zero.
# 00072_thickness_3.npy: 99.90% of the array cells are zero.
# 00072_thickness_7.npy: 99.82% of the array cells are zero.
# 00072_thickness_16.npy: 99.70% of the array cells are zero.
# 00072_thickness_6.npy: 99.85% of the array cells are zero.
# 00072_thickness_14.npy: 99.72% of the array cells are zero.
# 00072_thickness_4.npy: 99.90% of the array cells are zero.
# 00072_thickness_12.npy: 99.73% of the array cells are zero.
# 00072_thickness_19.npy: 99.72% of the array cells are zero.
# 00072_thickness_22.npy: 99.78% of the array cells are zero.
# 00072_thickness_20.npy: 99.75% of the array cells are zero.
# 00072_thickness_17.npy: 99.67% of the array cells are zero.
# 00072_thickness_9.npy: 99.78% of the array cells are zero.
# Average sparseness for thickness in model 00072: 99.78%
# Processing velocity for model_id: 00072
# 00072_velocity_20.npy: 99.62% of the array cells are zero.
# 00072_velocity_18.npy: 99.53% of the array cells are zero.
# 00072_velocity_16.npy: 99.54% of the array cells are zero.
# 00072_velocity_17.npy: 99.50% of the array cells are zero.
# 00072_velocity_6.npy: 99.78% of the array cells are zero.
# 00072_velocity_12.npy: 99.59% of the array cells are zero.
# 00072_velocity_19.npy: 99.57% of the array cells are zero.
# 00072_velocity_10.npy: 99.66% of the array cells are zero.
# 00072_velocity_11.npy: 99.63% of the array cells are zero.
# 00072_velocity_22.npy: 99.65% of the array cells are zero.
# 00072_velocity_7.npy: 99.74% of the array cells are zero.
# 00072_velocity_9.npy: 99.67% of the array cells are zero.
# 00072_velocity_5.npy: 99.82% of the array cells are zero.
# 00072_velocity_8.npy: 99.72% of the array cells are zero.
# 00072_velocity_15.npy: 99.55% of the array cells are zero.
# 00072_velocity_21.npy: 99.65% of the array cells are zero.
# 00072_velocity_13.npy: 99.58% of the array cells are zero.
# 00072_velocity_3.npy: 99.83% of the array cells are zero.
# 00072_velocity_14.npy: 99.56% of the array cells are zero.
# 00072_velocity_2.npy: 100.00% of the array cells are zero.
# 00072_velocity_4.npy: 99.84% of the array cells are zero.
# Average sparseness for velocity in model 00072: 99.67%

# %%
# Function to calculate the percentage of zeros in a numpy array
def calculate_zero_percentage(npy_file):
    array = np.load(npy_file)
    total_elements = array.size
    zero_count = np.count_nonzero(array == 0)
    zero_percentage = (zero_count / total_elements) * 100
    return zero_percentage

# Function to process files in a specified subdirectory (either 'thickness' or 'velocity') and accumulate sparseness
def process_data_type(data_type):
    zero_percentages = []
    for model_id in os.listdir(source_dir):
        model_dir = os.path.join(source_dir, model_id)
        if os.path.isdir(model_dir):
            data_path = os.path.join(model_dir, '04_FinalProcessedData_256', data_type)
            if os.path.isdir(data_path):
                for filename in os.listdir(data_path):
                    if filename.endswith('.npy'):
                        file_path = os.path.join(data_path, filename)
                        zero_percentage = calculate_zero_percentage(file_path)
                        zero_percentages.append(zero_percentage)
    if zero_percentages:
        avg_zero_percentage = sum(zero_percentages) / len(zero_percentages)
        return avg_zero_percentage
    return 0

# Calculate overall average sparseness for velocity and thickness
avg_sparseness_velocity = process_data_type('velocity')
avg_sparseness_thickness = process_data_type('thickness')

# Print the overall averages
print(f"Overall Average Sparseness for Velocity: {avg_sparseness_velocity:.2f}%")
print(f"Overall Average Sparseness for Thickness: {avg_sparseness_thickness:.2f}%")
# Out:
# Overall Average Sparseness for Velocity: 99.52%
# Overall Average Sparseness for Thickness: 99.76%
